# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import string
import re
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import os
import datetime
from datetime import timedelta, date
import random
from dateutil.relativedelta import relativedelta
import pickle
import operator

chromedriver = "/chromedriver"
os.environ["webdriver.chrome.driver"] = chromedriver

# %%
df_titles = pd.read_csv('list.csv', delimiter = ',', skipinitialspace = True)

# %%
df_titles.head()
# Out:
#                      title  year
# 0          The Breadwinner  2017
# 1  The Mountain Between Us  2017
# 2   The Sense of an Ending  2017
# 3    The House of Tomorrow  2017
# 4           The Dark Tower  2017

# %%
# import functions to scrape data from IMDB
from scrape_imdb import *

# %%
driver = webdriver.Chrome(chromedriver)
driver.get('http://www.google.com/')
time.sleep(10);

# %%
dict_imdb = {}
for i in range(len(df_titles)):
    title = df_titles['title'][i]
    year = df_titles['year'][i]
    dict_imdb[title] = get_data_imdb(title,year)

# %%
dict_imdb
# Out:
# {'A Christmas Carol': ['A Christmas Carol',
#   '2009',
#   '2009-11-06',
#   'PG',
#   '6.8',
#   200000000,
#   '96',
#   'Walt Disney Pictures',
#   ['Animation', 'Drama', 'Family'],
#   223175116.67],
#  "A Dog's Purpose": ["A Dog's Purpose",
#   '2017',
#   '2017-01-27',
#   'PG',
#   '6.9',
#   22000000,
#   '100',
#   'Amblin Entertainment',
#   ['Adventure', 'Comedy', 'Drama'],
#   nan],
#  'A Hologram for the King': ['A Hologram for the King',
#   '2016',
#   '2016-04-28',
#   'R',
#   '6.1',
#   30000000,
#   '98',
#   '',
#   ['Comedy', 'Drama', 'Romance'],
#   10278844.44],
#  'A Long Way Down': ['A Long Way Down',
#   '2014',
#   '2014-06-05',
#   'R',
#   '6.4',
#   nan,
#   '96',
#   'Wildgaze Films',
#   ['Comedy', 'Drama'],
#   nan],
#  'A Monster Calls': ['A Monster Calls',
#   '2016',
#   '2017-01-06',
#   'PG-13',
#   '7.5',
#   43000000,
#   '108',
#   'Apaches Entertainment',
#   ['Animation', 'Drama', 'Fantasy'],
#   nan],
#  'A Walk Among the Tombstones': ['A Walk Among the Tombstones',
#   '2014',
#   '2014-09-19',
#   'R',
#   '6.5',
#   28000000,
#   '114',
#   '',
#   ['Crime', 'Drama', 'Mystery'],
#   17868250.0],
#  'Abraham Lincoln: Vampire Hunter': ['Abraham Lincoln: Vampire Hunter',
#   '2012',
#   '2012-06-22',
#   'R',
#   '5.9',
#   69000000,
#   '105',
#   'Abraham Productions',
#   ['Action', 'Fantasy', 'Horror'],
#   49260560.0],
#  'Admission': ['Admission',
#   '2013',
#   '2013-03-22',
#   'PG-13',
#   '5.7',
#   13000000,
#   '107',
#   'Focus Features',
#   ['Comedy', 'Drama', 'Romance'],
#   64741750.0],
#  'Alexander and the Terrible, Horrible, No Good, Very Bad Day': ['Alexander and the Terrible, Horrible, No Good, Very Bad Day',
#   '2014',
#   '2014-10-10',
#   'PG',
#   '6.2',
#   28000000,
#   '81',
#   'Walt Disney Pictures',
#   ['Comedy', 'Family'],
#   24737840.0],
#  'Alice in Wonderland': ['Alice in Wonderland',
#   '2010',
#   '2010-03-05',
#   'PG',
#   '6.5',
#   200000000,
#   '108',
#   'Walt Disney Pictures',
#   ['Adventure', 'Family', 'Fantasy'],
#   169949988.89],
#  'An Invisible Sign of My Own': ['An Invisible Sign',
#   '2010',
#   '2010-10-07',
#   'PG-13',
#   '5.4',
#   nan,
#   '96',
#   '',
#   ['Comedy', 'Drama', 'Family'],
#   nan],
#  'Anna Karenina': ['Anna Karenina',
#   '2012',
#   '2012-09-07',
#   'R',
#   '6.6',
#   nan,
#   '129',
#   'Universal Pictures',
#   ['Drama', 'Romance'],
#   42827150.0],
#  'Another Bullshit Night in Suck City': ['Being Flynn',
#   '2012',
#   '2012-04-19',
#   'R',
#   '6.4',
#   nan,
#   '102',
#   'Focus Features',
#   ['Drama'],
#   64741750.0],
#  'Appaloosa': ['Appaloosa',
#   '2008',
#   '2008-10-03',
#   'R',
#   '6.8',
#   20000000,
#   '115',
#   'New Line Cinema',
#   ['Crime', 'Drama', 'Romance'],
#   19890050.0],
#  'Arrival': ['Arrival',
#   '2016',
#   '2016-11-11',
#   'PG-13',
#   '7.9',
#   47000000,
#   '116',
#   'Lava Bear Films',
#   ['Drama', 'Mystery', 'Sci-Fi'],
#   37905033.33],
#  'Atlas Shrugged': ['Atlas Shrugged: Part I',
#   '2011',
#   '2011-04-15',
#   'PG-13',
#   '5.7',
#   20000000,
#   '97',
#   'Atlas Productions See more',
#   ['Drama', 'Mystery', 'Sci-Fi'],
#   nan],
#  'Austenland': ['Austenland',
#   '2013',
#   '2013-09-27',
#   'PG-13',
#   '6.3',
#   4900000,
#   '97',
#   'Fickle Fish Films',
#   ['Comedy', 'Romance'],
#   nan],
#  'Beastly': ['Beastly',
#   '2011',
#   '2011-03-04',
#   'PG-13',
#   '5.6',
#   17000000,
#   '86',
#   'CBS Films',
#   ['Drama', 'Fantasy', 'Romance'],
#   13584266.67],
#  'Beautiful Creatures': ['Beautiful Creatures',
#   '2013',
#   '2013-02-14',
#   'PG-13',
#   '6.2',
#   60000000,
#   '124',
#   'Alcon Entertainment',
#   ['Drama', 'Fantasy', 'Romance'],
#   24606300.0],
#  'Beezus and Ramona': ['Ramona and Beezus',
#   '2010',
#   '2010-07-23',
#   'G',
#   '6.6',
#   15000000,
#   '103',
#   'Fox',
#   ['Adventure', 'Comedy', 'Family'],
#   nan],
#  'Before I Fall': ['Before I Fall',
#   '2017',
#   '2017-03-03',
#   'PG-13',
#   '6.4',
#   5000000,
#   '98',
#   'Awesomeness Films',
#   ['Drama', 'Mystery'],
#   nan],
#  'Before I Go to Sleep': ['Before I Go to Sleep',
#   '2014',
#   '2014-10-31',
#   'R',
#   '6.3',
#   22000000,
#   '92',
#   'Scott Free Productions',
#   ['Drama', 'Mystery', 'Thriller'],
#   1926300.0],
#  'Bel Ami': ['Bel Ami',
#   '2012',
#   '2012-03-09',
#   'R',
#   '5.4',
#   nan,
#   '102',
#   'Redwave Films',
#   ['Drama', 'History', 'Romance'],
#   nan],
#  'Ben-Hur': ['Ben-Hur',
#   '2016',
#   '2016-08-19',
#   'PG-13',
#   '5.7',
#   100000000,
#   '123',
#   'LightWorkers Media',
#   ['Action', 'Adventure', 'Drama'],
#   49260560.0],
#  'Berlin Syndrome': ['Berlin Syndrome',
#   '2017',
#   '2017-05-26',
#   'R',
#   '6.3',
#   nan,
#   '116',
#   'Aquarius Films',
#   ['Drama', 'Horror', 'Mystery'],
#   nan],
#  "Billy Lynn's Long Halftime Walk": ["Billy Lynn's Long Halftime Walk",
#   '2016',
#   '2016-11-18',
#   'R',
#   '6.3',
#   40000000,
#   '113',
#   'Bona Film Group',
#   ['Drama', 'War'],
#   63485792.31],
#  'Blindness': ['Blindness',
#   '2008',
#   '2008-10-03',
#   'R',
#   '6.6',
#   25000000,
#   '121',
#   'Rhombus Media',
#   ['Drama', 'Mystery', 'Sci-Fi'],
#   nan],
#  'Body of Lies': ['Body of Lies',
#   '2008',
#   '2008-10-10',
#   'R',
#   '7.1',
#   70000000,
#   '128',
#   'Warner Bro',
#   ['Action', 'Drama', 'Romance'],
#   113909863.64],
#  'Brideshead Revisited': ['Brideshead Revisited',
#   '2008',
#   '2008-08-15',
#   'PG-13',
#   '6.7',
#   20000000,
#   '133',
#   'Ecosse Films',
#   ['Drama', 'Romance'],
#   nan],
#  'Brighton Rock': ['Brighton Rock',
#   '2010',
#   '2011-02-04',
#   'R',
#   '5.8',
#   12000000,
#   '111',
#   'StudioCanal',
#   ['Crime', 'Drama', 'Thriller'],
#   1926300.0],
#  'Call of the Wild': ['Call of the Wild',
#   '2009',
#   '2009-06-12',
#   'PG',
#   '5.4',
#   nan,
#   '88',
#   'Braeburn Entertainment',
#   ['Adventure', 'Drama', 'Family'],
#   nan],
#  'Captain Underpants': ['Captain Underpants: The First Epic Movie',
#   '2017',
#   '2017-06-02',
#   'PG',
#   '6.2',
#   38000000,
#   '89',
#   'DreamWorks Animation',
#   ['Animation', 'Action', 'Comedy'],
#   97125100.0],
#  'Carrie': ['Carrie',
#   '2013',
#   '2013-10-18',
#   'R',
#   '5.9',
#   30000000,
#   '100',
#   'Metr',
#   ['Drama', 'Horror'],
#   24217600.0],
#  'Cell': ['Cell',
#   '2016',
#   '2016-06-10',
#   'R',
#   '4.3',
#   nan,
#   '98',
#   'Genre C',
#   ['Action', 'Drama', 'Horror'],
#   34338733.33],
#  'Charlie St. Cloud': ['Charlie St. Cloud',
#   '2010',
#   '2010-07-30',
#   'PG-13',
#   '6.5',
#   44000000,
#   '99',
#   'Universal Pictures',
#   ['Drama', 'Fantasy', 'Romance'],
#   33827775.0],
#  'Child 44': ['Child 44',
#   '2015',
#   '2015-04-17',
#   'R',
#   '6.5',
#   50000000,
#   '137',
#   'Worldview Entertainmen',
#   ['Crime', 'Drama', 'Thriller'],
#   44789450.0],
#  'Choke': ['Choke',
#   '2008',
#   '2008-09-26',
#   'R',
#   '6.5',
#   3000000,
#   '92',
#   'Fox Searchlight Pictures',
#   ['Comedy', 'Drama'],
#   3741700.0],
#  'City of Ember': ['City of Ember',
#   '2008',
#   '2008-10-10',
#   'PG',
#   '6.5',
#   55000000,
#   '90',
#   'Playtone',
#   ['Adventure', 'Family', 'Fantasy'],
#   54885266.67],
#  'Cloud Atlas': ['Cloud Atlas',
#   '2012',
#   '2012-10-26',
#   'R',
#   '7.5',
#   102000000,
#   '172',
#   'Cloud Atlas Productions',
#   ['Action', 'Drama', 'Mystery'],
#   10278844.44],
#  'Cloudy with a Chance of Meatballs': ['Cloudy with a Chance of Meatballs',
#   '2009',
#   '2009-09-18',
#   'PG',
#   '7.0',
#   100000000,
#   '90',
#   'Columbia Pictures',
#   ['Animation', 'Action', 'Adventure'],
#   205101250.0],
#  'Coraline': ['Coraline',
#   '2009',
#   '2009-02-06',
#   'PG',
#   '7.7',
#   60000000,
#   '100',
#   'Focus Features',
#   ['Animation', 'Family', 'Fantasy'],
#   76622375.0],
#  'Coriolanus': ['Coriolanus',
#   '2011',
#   '2012-01-20',
#   'R',
#   '6.2',
#   nan,
#   '123',
#   'Hermetof Pictures',
#   ['Drama', 'Thriller', 'War'],
#   1146550.0],
#  'Cosmopolis': ['Cosmopolis',
#   '2012',
#   '2012-05-25',
#   'R',
#   '5.0',
#   20500000,
#   '109',
#   'Alfama Films',
#   ['Drama', 'Fantasy'],
#   nan],
#  'Cowboys and Aliens': ['Cowboys & Aliens',
#   '2011',
#   '2011-07-29',
#   'PG-13',
#   '6.0',
#   163000000,
#   '119',
#   'Universal Pictures',
#   ['Action', 'Sci-Fi', 'Thriller'],
#   202383137.5],
#  'Dark Places': ['Dark Places',
#   '2015',
#   '2015-06-18',
#   'R',
#   '6.2',
#   20000000,
#   '113',
#   'Exclusive Media Grou',
#   ['Action', 'Drama', 'Mystery'],
#   nan],
#  'Dear John': ['Dear John',
#   '2010',
#   '2010-02-05',
#   'PG-13',
#   '6.3',
#   25000000,
#   '108',
#   'Screen Gems',
#   ['Drama', 'Romance', 'War'],
#   nan],
#  'Diary of a Wimpy Kid': ['Diary of a Wimpy Kid',
#   '2010',
#   '2010-03-19',
#   'PG',
#   '6.2',
#   15000000,
#   '94',
#   'Color Force',
#   ['Comedy', 'Family'],
#   81393433.33],
#  'Divergent': ['Divergent',
#   '2014',
#   '2014-03-21',
#   'PG-13',
#   '6.7',
#   85000000,
#   '139',
#   'Summit Entertainment',
#   ['Adventure', 'Mystery', 'Sci-Fi'],
#   63556180.0],
#  "Ender's Game": ["Ender's Game",
#   '2013',
#   '2013-11-01',
#   'PG-13',
#   '6.7',
#   110000000,
#   '114',
#   'MWM',
#   ['Action', 'Fantasy', 'Sci-Fi'],
#   nan],
#  'Everything, Everything': ['Everything, Everything',
#   '2017',
#   '2017-05-19',
#   'PG-13',
#   '6.4',
#   10000000,
#   '96',
#   'Alloy Entertainment',
#   ['Drama', 'Romance'],
#   nan],
#  'Extremely Loud and Incredibly Close': ['Extremely Loud & Incredibly Close',
#   '2011',
#   '2012-01-20',
#   'PG-13',
#   '6.9',
#   40000000,
#   '129',
#   'Warner Bro',
#   ['Adventure', 'Drama', 'Mystery'],
#   35901940.0],
#  'Fallen': ['Fallen',
#   '2016',
#   '2017-09-08',
#   'PG-13',
#   '5.5',
#   nan,
#   '91',
#   'Apex Entertainment',
#   ['Adventure', 'Drama', 'Fantasy'],
#   37493928.57],
#  'Fantastic Mr. Fox': ['Fantastic Mr. Fox',
#   '2009',
#   '2009-11-25',
#   'PG',
#   '7.8',
#   40000000,
#   '87',
#   'Twentieth Century Fox',
#   ['Animation', 'Adventure', 'Comedy'],
#   38763412.5],
#  'Far from the Madding Crowd': ['Far from the Madding Crowd',
#   '2015',
#   '2015-05-22',
#   'PG-13',
#   '7.1',
#   12000000,
#   '119',
#   'Fox Searchlight Picture',
#   ['Drama', 'Romance'],
#   nan],
#  'Fifty Shades of Grey': ['Fifty Shades of Grey',
#   '2015',
#   '2015-02-13',
#   'R',
#   '4.1',
#   40000000,
#   '125',
#   'Focus Features',
#   ['Drama', 'Romance', 'Thriller'],
#   nan],
#  'Flipped': ['Flipped',
#   '2010',
#   '2010-09-10',
#   'PG',
#   '7.7',
#   14000000,
#   '90',
#   'Castle Rock Entertainment See more',
#   ['Comedy', 'Drama', 'Romance'],
#   75638327.78],
#  'Frankenstein': ['Frankenstein',
#   '2015',
#   '2015-10-29',
#   'R',
#   '5.1',
#   nan,
#   '89',
#   'Bad Badge',
#   ['Horror', 'Thriller'],
#   nan],
#  'Garden of Eden': ['The Garden of Eden',
#   '2008',
#   '2011-09-15',
#   'R',
#   '5.4',
#   nan,
#   '111',
#   'Devonshire Productions',
#   ['Drama', 'Thriller'],
#   nan],
#  'Gone Girl': ['Gone Girl',
#   '2014',
#   '2014-10-03',
#   'R',
#   '8.1',
#   61000000,
#   '149',
#   'Twentieth Century Fox',
#   ['Crime', 'Drama', 'Mystery'],
#   126710530.0],
#  'Goosebumps': ['Goosebumps',
#   '2015',
#   '2015-10-16',
#   'PG',
#   '6.3',
#   58000000,
#   '103',
#   'Columbia Pictures',
#   ['Adventure', 'Comedy', 'Family'],
#   153984400.0],
#  'Great Expectations': ['Great Expectations',
#   '2012',
#   '2013-11-08',
#   'PG-13',
#   '6.4',
#   nan,
#   '128',
#   'BBC Films',
#   ['Drama', 'Romance'],
#   65199971.43],
#  "Gulliver's Travels": ["Gulliver's Travels",
#   '2010',
#   '2010-12-25',
#   'PG',
#   '4.9',
#   112000000,
#   '85',
#   'Twentieth Century Fox',
#   ['Adventure', 'Comedy', 'Family'],
#   153984400.0],
#  'Hector and the Search for Happiness': ['Hector and the Search for Happiness',
#   '2014',
#   '2014-08-14',
#   'R',
#   '7.0',
#   nan,
#   '114',
#   'Egoli Tossell Film',
#   ['Adventure', 'Comedy', 'Drama'],
#   33467822.22],
#  'Here Be Monsters': ['Here Be Monsters',
#   '2014',
#   '2014-07-22',
#   nan,
#   nan,
#   nan,
#   '15',
#   nan,
#   ['Short', 'Drama', 'Fantasy'],
#   nan],
#  'Horns': ['Horns',
#   '2013',
#   '2014-10-03',
#   'R',
#   '6.5',
#   nan,
#   '120',
#   'Red Granite Pictures',
#   ['Drama', 'Fantasy', 'Horror'],
#   nan],
#  'Horrid Henry': ['Horrid Henry: The Movie',
#   '2011',
#   '2013-01-11',
#   'PG',
#   '3.7',
#   nan,
#   '93',
#   'Vertigo Films',
#   ['Adventure', 'Comedy', 'Family'],
#   nan],
#  'Horton Hears a Who': ['Horton Hears a Who!',
#   '2008',
#   '2008-03-14',
#   'G',
#   '6.8',
#   85000000,
#   '86',
#   'Blue Sky Studios',
#   ['Animation', 'Adventure', 'Comedy'],
#   90437766.67],
#  'Hotel for Dogs': ['Hotel for Dogs',
#   '2009',
#   '2009-01-16',
#   'PG',
#   '5.4',
#   35000000,
#   '100',
#   'DreamWorks',
#   ['Comedy', 'Family'],
#   81393433.33],
#  'House': ['House',
#   '2008',
#   '2008-11-07',
#   'R',
#   '4.7',
#   2500000,
#   '88',
#   'More Entertainment',
#   ['Drama', 'Horror', 'Thriller'],
#   nan],
#  'How to Be Single': ['How to Be Single',
#   '2016',
#   '2016-02-12',
#   'R',
#   '6.1',
#   38000000,
#   '110',
#   'New Line Cinema',
#   ['Comedy', 'Romance'],
#   nan],
#  'How to Train Your Dragon': ['How to Train Your Dragon',
#   '2010',
#   '2010-03-26',
#   'PG',
#   '8.1',
#   165000000,
#   '98',
#   'DreamWorks Animation',
#   ['Animation', 'Action', 'Adventure'],
#   230986133.33],
#  'I Am Number Four': ['I Am Number Four',
#   '2011',
#   '2011-02-18',
#   'PG-13',
#   '6.1',
#   60000000,
#   '111',
#   'DreamWorks',
#   ['Action', 'Adventure', 'Sci-Fi'],
#   nan],
#  'I Love You, Beth Cooper': ['I Love You, Beth Cooper',
#   '2009',
#   '2009-07-10',
#   'PG-13',
#   '5.3',
#   18000000,
#   '102',
#   'Fox Atomic',
#   ['Comedy', 'Romance'],
#   215013946.67],
#  'If I Stay': ['If I Stay',
#   '2014',
#   '2014-08-22',
#   'PG-13',
#   '6.8',
#   11000000,
#   '107',
#   'DiNovi Pictures',
#   ['Drama', 'Fantasy', 'Music'],
#   nan],
#  'Inherent Vice': ['Inherent Vice',
#   '2014',
#   '2015-01-09',
#   'R',
#   '6.7',
#   20000000,
#   '148',
#   'Ghoulardi Film Company',
#   ['Comedy', 'Crime', 'Drama'],
#   28470028.57],
#  'Inkheart': ['Inkheart',
#   '2008',
#   '2009-01-23',
#   'PG',
#   '6.1',
#   60000000,
#   '106',
#   'New Line Cinema',
#   ['Adventure', 'Family', 'Fantasy'],
#   36690700.0],
#  'Into the Forest': ['Into the Forest',
#   '2015',
#   '2016-07-29',
#   'R',
#   '5.9',
#   nan,
#   '101',
#   'Rhombus Media',
#   ['Drama', 'Sci-Fi', 'Thriller'],
#   nan],
#  'It': ['It',
#   '2017',
#   '2017-09-08',
#   'R',
#   '7.5',
#   35000000,
#   '135',
#   'New Line Cinema',
#   ['Drama', 'Horror', 'Thriller'],
#   nan],
#  "It's Kind of a Funny Story": ["It's Kind of a Funny Story",
#   '2010',
#   '2010-10-08',
#   'PG-13',
#   '7.1',
#   8000000,
#   '101',
#   'Focus Features',
#   ['Comedy', 'Drama', 'Romance'],
#   3028408.33],
#  'Jane Eyre': ['Jane Eyre',
#   '2011',
#   '2011-04-22',
#   'PG-13',
#   '7.4',
#   nan,
#   '120',
#   'Focus Features',
#   ['Drama', 'Romance'],
#   nan],
#  'Journey to the Center of the Earth': ['Journey to the Center of the Earth',
#   '2008',
#   '2008-07-11',
#   'PG',
#   '5.8',
#   45000000,
#   '93',
#   'New Line Cinema',
#   ['Action', 'Adventure', 'Family'],
#   nan],
#  'Jumper': ['Jumper',
#   '2008',
#   '2008-02-14',
#   'PG-13',
#   '6.1',
#   85000000,
#   '88',
#   'Twentieth Century Fox',
#   ['Action', 'Adventure', 'Sci-Fi'],
#   103396228.57],
#  'Killshot': ['Killshot',
#   '2008',
#   '2008-11-13',
#   'R',
#   '6.0',
#   nan,
#   '95',
#   'The Weinstein Company',
#   ['Crime', 'Drama', 'Thriller'],
#   34890181.82],
#  'Kit an American Girl': ['Kit Kittredge: An American Girl',
#   '2008',
#   '2008-07-02',
#   'G',
#   '6.6',
#   10000000,
#   '101',
#   'Picturehouse',
#   ['Drama', 'Family'],
#   nan],
#  'Labor Day': ['Labor Day',
#   '2013',
#   '2014-01-31',
#   'PG-13',
#   '6.9',
#   18000000,
#   '111',
#   'Indian Paintbrush',
#   ['Drama', 'Romance'],
#   58807166.67],
#  "Legend of the Guardians: The Owls of Ga'hoole": ["Legend of the Guardians: The Owls of Ga'Hoole",
#   '2010',
#   '2010-09-24',
#   'PG',
#   '7.0',
#   80000000,
#   '97',
#   'Warner Bro',
#   ['Animation', 'Action', 'Adventure'],
#   183172728.57],
#  'Les Miserables': ['Les Misérables',
#   '2012',
#   '2012-12-25',
#   'PG-13',
#   '7.6',
#   61000000,
#   '158',
#   'Working Title Films',
#   ['Drama', 'History', 'Musical'],
#   86366600.0],
#  'Let Me In': ['Let Me In',
#   '2010',
#   '2010-10-01',
#   'R',
#   '7.1',
#   20000000,
#   '116',
#   'Overture Films',
#   ['Drama', 'Fantasy', 'Horror'],
#   91225650.0],
#  'Let the Right One In': ['Let the Right One In',
#   '2008',
#   '2008-12-12',
#   'R',
#   '7.9',
#   4000000,
#   '115',
#   'EFTI',
#   ['Drama', 'Horror', 'Romance'],
#   15351350.0],
#  'Life of Pi': ['Life of Pi',
#   '2012',
#   '2012-11-21',
#   'PG',
#   '7.9',
#   120000000,
#   '127',
#   'Fox',
#   ['Adventure', 'Drama', 'Fantasy'],
#   63485792.31],
#  'Live By Night': ['Live by Night',
#   '2016',
#   '2017-01-13',
#   'R',
#   '6.4',
#   108000000,
#   '129',
#   'Appian Way',
#   ['Action', 'Crime', 'Drama'],
#   75370425.0],
#  'Mars Needs Moms': ['Mars Needs Moms',
#   '2011',
#   '2011-03-11',
#   'PG',
#   '5.4',
#   150000000,
#   '88',
#   'Walt Disney Pictures',
#   ['Animation', 'Adventure', 'Family'],
#   66539150.0],
#  'Me Before You': ['Me Before You',
#   '2016',
#   '2016-06-03',
#   'PG-13',
#   '7.4',
#   20000000,
#   '106',
#   'Metr',
#   ['Drama', 'Romance'],
#   nan],
#  'Me and Earl and the Dying Girl': ['Me and Earl and the Dying Girl',
#   '2015',
#   '2015-07-01',
#   'PG-13',
#   '7.8',
#   8000000,
#   '105',
#   'Indian Paintbrush See more',
#   ['Comedy', 'Drama'],
#   nan],
#  'Middle School: the Worst Years of My Life': ['Middle School: The Worst Years of My Life',
#   '2016',
#   '2016-10-07',
#   'PG',
#   '6.1',
#   8500000,
#   '92',
#   'CBS Films',
#   ['Animation', 'Comedy', 'Family'],
#   92643575.0],
#  'Mildred Pierce': ['Mildred Pierce',
#   'Drama',
#   nan,
#   'TV-MA',
#   '7.7',
#   nan,
#   '336',
#   'Home Box Office',
#   ['Drama'],
#   nan],
#  'Miracle at St. Anna': ['Miracle at St. Anna',
#   '2008',
#   '2008-09-26',
#   'R',
#   '6.0',
#   45000000,
#   '160',
#   '',
#   ['Action', 'Crime', 'Drama'],
#   33919785.71],
#  "Miss Peregrine's Home for Peculiar Children": ["Miss Peregrine's Home for Peculiar Children",
#   '2016',
#   '2016-09-30',
#   'PG-13',
#   '6.7',
#   110000000,
#   '127',
#   'Twentieth Century Fox',
#   ['Adventure', 'Drama', 'Family'],
#   169949988.89],
#  'Miss Pettigrew Lives for a Day': ['Miss Pettigrew Lives for a Day',
#   '2008',
#   '2008-03-07',
#   'PG-13',
#   '7.1',
#   nan,
#   '92',
#   'Focus Features',
#   ['Comedy', 'Romance'],
#   nan],
#  "Mr. Popper's Penguins": ["Mr. Popper's Penguins",
#   '2011',
#   '2011-06-17',
#   'PG',
#   '6.0',
#   55000000,
#   '94',
#   'Twentieth Century Fox',
#   ['Comedy', 'Family', 'Fantasy'],
#   nan],
#  'Murder on the Orient Express': ['Murder on the Orient Express',
#   '2017',
#   '2017-11-10',
#   'PG-13',
#   '6.6',
#   55000000,
#   '114',
#   'Twentieth Century Fox',
#   ['Crime', 'Drama', 'Mystery'],
#   59281025.0],
#  'My Cousin Rachel': ['My Cousin Rachel',
#   '2017',
#   '2017-06-09',
#   'PG-13',
#   '6.0',
#   nan,
#   '106',
#   'Fox Searchlight Pictures',
#   ['Drama', 'Mystery', 'Romance'],
#   nan],
#  "My Sister's Keeper": ["My Sister's Keeper",
#   '2009',
#   '2009-06-26',
#   'PG-13',
#   '7.4',
#   30000000,
#   '109',
#   'Curmudgeon Films',
#   ['Drama', 'Family'],
#   60242485.71],
#  'Nerve': ['Nerve',
#   '2016',
#   '2016-07-27',
#   'PG-13',
#   '6.6',
#   20000000,
#   '96',
#   'Allison Shearmur Productions',
#   ['Action', 'Adventure', 'Crime'],
#   57201325.0],
#  'Never Let Me Go': ['Never Let Me Go',
#   '2010',
#   '2010-10-15',
#   'R',
#   '7.2',
#   15000000,
#   '103',
#   'DNA Films',
#   ['Drama', 'Romance', 'Sci-Fi'],
#   26368900.0],
#  "Nick and Norah's Infinite Playlist": ["Nick and Norah's Infinite Playlist",
#   '2008',
#   '2008-10-03',
#   'PG-13',
#   '6.7',
#   9000000,
#   '90',
#   'Screen Gems',
#   ['Comedy', 'Drama', 'Music'],
#   nan],
#  'Nights in Rodanthe': ['Nights in Rodanthe',
#   '2008',
#   '2008-09-26',
#   'PG-13',
#   '6.0',
#   30000000,
#   '97',
#   'Warner Bro',
#   ['Drama', 'Romance'],
#   nan],
#  'On the Road': ['On the Road',
#   '2012',
#   '2012-05-23',
#   'R',
#   '6.1',
#   25000000,
#   '124',
#   'M',
#   ['Adventure', 'Drama', 'Romance'],
#   nan],
#  'One Day': ['One Day',
#   '2011',
#   '2011-08-19',
#   'PG-13',
#   '7.0',
#   15000000,
#   '107',
#   'Focus Features',
#   ['Drama', 'Romance'],
#   6994420.0],
#  'One for the Money': ['One for the Money',
#   '2012',
#   '2012-01-27',
#   'PG-13',
#   '5.3',
#   40000000,
#   '91',
#   'Lakeshore Entertainment',
#   ['Action', 'Comedy', 'Crime'],
#   51978250.0],
#  'Paper Towns': ['Paper Towns',
#   '2015',
#   '2015-07-24',
#   'PG-13',
#   '6.3',
#   12000000,
#   '109',
#   'Fox 2000 Picture',
#   ['Drama', 'Mystery', 'Romance'],
#   19756450.0],
#  'Paranoia': ['Paranoia',
#   '2013',
#   '2013-08-16',
#   'PG-13',
#   '5.7',
#   35000000,
#   '106',
#   'Relativity Media',
#   ['Action', 'Crime', 'Drama'],
#   82474900.0],
#  'Percy Jackson & the Olympians: The Lightning Thief': ['Percy Jackson & the Olympians: The Lightning Thief',
#   '2010',
#   '2010-02-12',
#   'PG',
#   '5.9',
#   95000000,
#   '118',
#   'Fox',
#   ['Adventure', 'Family', 'Fantasy'],
#   215013946.67],
#  'Pride and Prejudice and Zombies': ['Pride and Prejudice and Zombies',
#   '2016',
#   '2016-02-05',
#   'PG-13',
#   '5.8',
#   28000000,
#   '108',
#   'Cross Creek Pictures',
#   ['Action', 'Horror', 'Romance'],
#   33827775.0],
#  'Priest': ['Priest',
#   '2011',
#   '2011-05-13',
#   'PG-13',
#   '5.7',
#   60000000,
#   '87',
#   'Screen Gems',
#   ['Action', 'Fantasy', 'Horror'],
#   nan],
#  'Radio Free Albemuth': ['Radio Free Albemuth',
#   '2010',
#   '2014-06-27',
#   'R',
#   '5.7',
#   3600000,
#   '111',
#   nan,
#   ['Drama', 'Sci-Fi'],
#   nan],
#  'Red': ['RED',
#   '2010',
#   '2010-10-15',
#   'PG-13',
#   '7.1',
#   58000000,
#   '111',
#   'Summit Entertainment',
#   ['Action', 'Comedy', 'Crime'],
#   93822200.0],
#  'Red Riding Hood': ['Red Riding Hood',
#   '2011',
#   '2011-03-11',
#   'PG-13',
#   '5.4',
#   42000000,
#   '100',
#   'Warner Bro',
#   ['Fantasy', 'Horror', 'Mystery'],
#   52255514.29],
#  'Revenant': ['The Revenant',
#   '2015',
#   '2016-01-08',
#   'R',
#   '8.0',
#   135000000,
#   '156',
#   'Regency Enterprises',
#   ['Adventure', 'Drama', 'History'],
#   nan],
#  'Revolutionary Road': ['Revolutionary Road',
#   '2008',
#   '2009-01-23',
#   'R',
#   '7.3',
#   35000000,
#   '119',
#   'DreamWorks',
#   ['Drama', 'Romance'],
#   154577742.86],
#  'Room': ['Room',
#   '2015',
#   '2016-01-22',
#   'R',
#   '8.2',
#   13000000,
#   '118',
#   'Element Pictures',
#   ['Drama'],
#   nan],
#  'Safe Haven': ['Safe Haven',
#   '2013',
#   '2013-02-14',
#   'PG-13',
#   '6.7',
#   28000000,
#   '115',
#   'Relativity Media',
#   ['Drama', 'Romance', 'Thriller'],
#   nan],
#  'Salmon Fishing in the Yemen': ['Salmon Fishing in the Yemen',
#   '2011',
#   '2012-04-20',
#   'PG-13',
#   '6.8',
#   nan,
#   '107',
#   'UK Film Council',
#   ['Comedy', 'Drama', 'Romance'],
#   nan],
#  'Savages': ['Savages',
#   '2012',
#   '2012-07-06',
#   'R',
#   '6.5',
#   45000000,
#   '131',
#   'Ixtlan',
#   ['Crime', 'Drama', 'Romance'],
#   75752368.42],
#  'Scott Pilgrim vs the World': ['Scott Pilgrim vs. the World',
#   '2010',
#   '2010-08-13',
#   'PG-13',
#   '7.5',
#   60000000,
#   '112',
#   'Universal Pictures',
#   ['Action', 'Comedy', 'Romance'],
#   29875775.0],
#  'Secret in Their Eyes': ['Secret in Their Eyes',
#   '2015',
#   '2015-11-20',
#   'PG-13',
#   '6.3',
#   19500000,
#   '111',
#   'IM Global',
#   ['Crime', 'Drama', 'Mystery'],
#   23002333.33],
#  'Serena': ['Serena',
#   '2014',
#   '2015-02-26',
#   'R',
#   '5.4',
#   30000000,
#   '109',
#   '2929 Production',
#   ['Drama', 'Romance'],
#   nan],
#  'Sherlock Holmes': ['Sherlock Holmes',
#   '2009',
#   '2009-12-25',
#   'PG-13',
#   '7.6',
#   90000000,
#   '128',
#   'Warner Bro',
#   ['Action', 'Adventure', 'Crime'],
#   72442487.5],
#  'Shutter Island': ['Shutter Island',
#   '2010',
#   '2010-02-19',
#   'R',
#   '8.1',
#   80000000,
#   '138',
#   'Paramount Pictures',
#   ['Mystery', 'Thriller'],
#   77219733.33],
#  'Snow Flower and the Secret Fan': ['Snow Flower and the Secret Fan',
#   '2011',
#   '2011-06-24',
#   'PG-13',
#   '6.1',
#   6000000,
#   '120',
#   'IDG China Media See more',
#   ['Drama', 'History'],
#   nan],
#  'Something Borrowed': ['Something Borrowed',
#   '2011',
#   '2011-05-06',
#   'PG-13',
#   '5.9',
#   35000000,
#   '112',
#   'Alcon Entertainment',
#   ['Comedy', 'Drama', 'Romance'],
#   63294950.0],
#  'Still Alice': ['Still Alice',
#   '2014',
#   '2015-02-20',
#   'PG-13',
#   '7.5',
#   5000000,
#   '101',
#   'Lutzu',
#   ['Drama'],
#   6178050.0],
#  'Syrup': ['Syrup',
#   '2013',
#   '2013-05-01',
#   'R',
#   '5.7',
#   2500000,
#   '90',
#   'Lila',
#   ['Comedy', 'Drama', 'Romance'],
#   nan],
#  'The 5th Wave': ['The 5th Wave',
#   '2016',
#   '2016-01-22',
#   'PG-13',
#   '5.2',
#   38000000,
#   '112',
#   'Columbia Pictures',
#   ['Action', 'Adventure', 'Sci-Fi'],
#   nan],
#  'The BFG': ['The BFG',
#   '2016',
#   '2016-07-01',
#   'PG',
#   '6.4',
#   140000000,
#   '117',
#   'Walt Disney Pictures',
#   ['Adventure', 'Family', 'Fantasy'],
#   323270386.67],
#  'The Best of Me': ['The Best of Me',
#   '2014',
#   '2014-10-17',
#   'PG-13',
#   '6.7',
#   26000000,
#   '118',
#   'DiNovi Pictures',
#   ['Drama', 'Romance'],
#   27145540.0],
#  'The Boy in the Striped Pyjamas': ['The Boy in the Striped Pajamas',
#   '2008',
#   '2008-11-26',
#   'PG-13',
#   '7.8',
#   12500000,
#   '94',
#   'Miramax',
#   ['Drama', 'War'],
#   nan],
#  'The Breadwinner': ['The Breadwinner',
#   '2017',
#   '2017-11-17',
#   'PG-13',
#   '7.6',
#   nan,
#   '94',
#   'Aircraft Pictures',
#   ['Animation', 'Drama', 'Family'],
#   nan],
#  'The Choice': ['The Choice',
#   '2016',
#   '2016-02-05',
#   'PG-13',
#   '6.6',
#   nan,
#   '111',
#   'Nicholas Sparks Productions',
#   ['Drama', 'Romance'],
#   20040700.0],
#  'The Circle': ['The Circle',
#   '2017',
#   '2017-04-28',
#   'PG-13',
#   '5.3',
#   18000000,
#   '110',
#   '',
#   ['Drama', 'Sci-Fi', 'Thriller'],
#   6564940.0],
#  'The Company You Keep': ['The Company You Keep',
#   '2012',
#   '2013-04-26',
#   'R',
#   '6.4',
#   2000000,
#   '125',
#   'Voltage Pictures',
#   ['Drama', 'Thriller'],
#   67442188.89],
#  'The Curious Case of Benjamin Button': ['The Curious Case of Benjamin Button',
#   '2008',
#   '2008-12-25',
#   'PG-13',
#   '7.8',
#   150000000,
#   '166',
#   'Warner Bro',
#   ['Drama', 'Fantasy', 'Romance'],
#   126710530.0],
#  'The DUFF': ['The DUFF',
#   '2015',
#   '2015-02-20',
#   'PG-13',
#   '6.5',
#   8500000,
#   '101',
#   'CBS Film',
#   ['Comedy', 'Romance'],
#   38395100.0],
#  'The Dark Tower': ['The Dark Tower',
#   '2017',
#   '2017-08-04',
#   'PG-13',
#   '5.7',
#   60000000,
#   '95',
#   'Sony Pictures Entertainment',
#   ['Action', 'Adventure', 'Fantasy'],
#   nan],
#  'The Dinner': ['The Dinner',
#   '2017',
#   '2017-05-05',
#   'R',
#   '4.5',
#   nan,
#   '120',
#   'ChubbCo Film',
#   ['Crime', 'Drama', 'Thriller'],
#   872633.33],
#  'The Driftless Area': ['The Driftless Area',
#   '2015',
#   '2016-04-26',
#   'R',
#   '5.3',
#   nan,
#   '95',
#   'Unified Pictures',
#   ['Crime', 'Drama'],
#   nan],
#  'The Fault in Our Stars': ['The Fault in Our Stars',
#   '2014',
#   '2014-06-06',
#   'PG-13',
#   '7.8',
#   12000000,
#   '126',
#   'Fox',
#   ['Drama', 'Romance'],
#   69197300.0],
#  'The Girl on the Train': ['The Girl on the Train',
#   '2016',
#   '2016-10-07',
#   'R',
#   '6.5',
#   45000000,
#   '112',
#   'Amblin Partners',
#   ['Crime', 'Drama', 'Mystery'],
#   77514100.0],
#  'The Girl with the Dragon Tattoo': ['The Girl with the Dragon Tattoo',
#   '2011',
#   '2011-12-21',
#   'R',
#   '7.8',
#   90000000,
#   '158',
#   'Columbia Pictures',
#   ['Crime', 'Drama', 'Mystery'],
#   126710530.0],
#  'The Giver': ['The Giver',
#   '2014',
#   '2014-08-15',
#   'PG-13',
#   '6.5',
#   25000000,
#   '97',
#   'Tonik Productions',
#   ['Drama', 'Romance', 'Sci-Fi'],
#   79007884.62],
#  'The Great Gatsby': ['The Great Gatsby',
#   '2013',
#   '2013-05-10',
#   'PG-13',
#   '7.3',
#   105000000,
#   '143',
#   'Warner Bro',
#   ['Drama', 'Romance'],
#   87366120.0],
#  'The Help': ['The Help',
#   '2011',
#   '2011-08-10',
#   'PG-13',
#   '8.1',
#   25000000,
#   '146',
#   'DreamWorks',
#   ['Drama'],
#   77514100.0],
#  'The Host': ['The Host',
#   '2013',
#   '2013-03-29',
#   'PG-13',
#   '5.9',
#   40000000,
#   '125',
#   'Chockstone Pictures',
#   ['Action', 'Adventure', 'Romance'],
#   24741566.67],
#  'The House of Tomorrow': ['The House of Tomorrow',
#   '2017',
#   '2017-04-08',
#   nan,
#   '8.1',
#   nan,
#   '85',
#   'Superlative Films',
#   ['Comedy', 'Drama'],
#   nan],
#  'The Hundred-Foot Journey': ['The Hundred-Foot Journey',
#   '2014',
#   '2014-08-08',
#   'PG',
#   '7.3',
#   22000000,
#   '122',
#   'Amblin Entertainment',
#   ['Comedy', 'Drama'],
#   nan],
#  'The Hunger Games': ['The Hunger Games',
#   '2012',
#   '2012-03-23',
#   'PG-13',
#   '7.2',
#   78000000,
#   '142',
#   'Lionsgate',
#   ['Adventure', 'Sci-Fi', 'Thriller'],
#   187713875.0],
#  'The Informers': ['The Informers',
#   '2008',
#   '2009-04-24',
#   'R',
#   '5.0',
#   18000000,
#   '98',
#   'Senator Entertainment Co See more',
#   ['Crime', 'Drama', 'Thriller'],
#   nan],
#  'The Jungle Book': ['The Jungle Book',
#   '2016',
#   '2016-04-15',
#   'PG',
#   '7.5',
#   175000000,
#   '106',
#   'Fairview Entertainment',
#   ['Adventure', 'Drama', 'Family'],
#   202383137.5],
#  'The Killer Inside Me': ['The Killer Inside Me',
#   '2010',
#   '2010-06-08',
#   'R',
#   '6.1',
#   13000000,
#   '109',
#   'Hero Entertainment',
#   ['Crime', 'Drama', 'Thriller'],
#   1403105.26],
#  'The Last Song': ['The Last Song',
#   '2010',
#   '2010-03-31',
#   'PG',
#   '5.9',
#   20000000,
#   '107',
#   'Touchstone Pictures',
#   ['Drama', 'Music', 'Romance'],
#   51978250.0],
#  'The Last Station': ['The Last Station',
#   '2009',
#   '2010-02-26',
#   'R',
#   '7.0',
#   13000000,
#   '112',
#   'Egoli Tossell Film',
#   ['Biography', 'Drama', 'Romance'],
#   27145540.0],
#  'The Life Before Her Eyes': ['The Life Before Her Eyes',
#   '2007',
#   '2008-09-05',
#   'R',
#   '6.4',
#   8000000,
#   '90',
#   '',
#   ['Drama', 'Fantasy', 'Mystery'],
#   nan],
#  'The Light Between Oceans': ['The Light Between Oceans',
#   '2016',
#   '2016-09-02',
#   'PG-13',
#   '7.2',
#   20000000,
#   '133',
#   'Heyday Films',
#   ['Drama', 'Romance'],
#   16099566.67],
#  'The Lincoln Lawyer': ['The Lincoln Lawyer',
#   '2011',
#   '2011-03-18',
#   'R',
#   '7.3',
#   40000000,
#   '118',
#   'Lionsgate',
#   ['Crime', 'Drama', 'Thriller'],
#   34969500.0],
#  'The Longest Ride': ['The Longest Ride',
#   '2015',
#   '2015-04-10',
#   'PG-13',
#   '7.1',
#   34000000,
#   '123',
#   'Fox 2000 Picture',
#   ['Drama', 'Romance'],
#   nan],
#  'The Lorax': ['The Lorax',
#   '2012',
#   '2012-03-02',
#   'PG',
#   '6.4',
#   70000000,
#   '86',
#   'Universal Pictures',
#   ['Animation', 'Adventure', 'Comedy'],
#   343539925.0],
#  'The Lovely Bones': ['The Lovely Bones',
#   '2009',
#   '2010-01-15',
#   'PG-13',
#   '6.7',
#   65000000,
#   '135',
#   'DreamWorks',
#   ['Drama', 'Fantasy', 'Thriller'],
#   243631908.33],
#  'The Lucky One': ['The Lucky One',
#   '2012',
#   '2012-04-20',
#   'PG-13',
#   '6.5',
#   25000000,
#   '101',
#   'Warner Bro',
#   ['Drama', 'Romance'],
#   37493928.57],
#  'The Martian': ['The Martian',
#   '2015',
#   '2015-10-02',
#   'PG-13',
#   '8.0',
#   108000000,
#   '144',
#   'Twentieth Century Fo',
#   ['Adventure', 'Drama', 'Sci-Fi'],
#   113909863.64],
#  'The Maze Runner': ['The Maze Runner',
#   '2014',
#   '2014-09-19',
#   'PG-13',
#   '6.8',
#   34000000,
#   '113',
#   'Twentieth Century Fox',
#   ['Action', 'Mystery', 'Sci-Fi'],
#   101447600.0],
#  'The Mortal Instruments: City of Bones': ['The Mortal Instruments: City of Bones',
#   '2013',
#   '2013-08-21',
#   'PG-13',
#   '5.9',
#   60000000,
#   '130',
#   'Constantin Film',
#   ['Action', 'Fantasy', 'Horror'],
#   74206280.0],
#  'The Mountain Between Us': ['The Mountain Between Us',
#   '2017',
#   '2017-10-06',
#   'PG-13',
#   '6.4',
#   35000000,
#   '112',
#   'Chernin Entertainment',
#   ['Action', 'Adventure', 'Drama'],
#   nan],
#  'The Ninth Life of Louis Drax': ['The 9th Life of Louis Drax',
#   '2016',
#   '2016-09-02',
#   'R',
#   '6.3',
#   nan,
#   '108',
#   'Brightlight Pictures',
#   ['Mystery', 'Thriller'],
#   nan],
#  'The Other Boleyn Girl': ['The Other Boleyn Girl',
#   '2008',
#   '2008-02-29',
#   'PG-13',
#   '6.7',
#   35000000,
#   '115',
#   'Columbia Pictures',
#   ['Biography', 'Drama', 'History'],
#   14712366.67],
#  'The Perks of Being a Wallflower': ['The Perks of Being a Wallflower',
#   '2012',
#   '2012-10-12',
#   'PG-13',
#   '8.0',
#   13000000,
#   '102',
#   'Summit Entertainment',
#   ['Drama', 'Romance'],
#   20254700.0],
#  'The Reader': ['The Reader',
#   '2008',
#   '2009-01-30',
#   'R',
#   '7.6',
#   32000000,
#   '124',
#   'The Weinstein Company',
#   ['Drama', 'Romance'],
#   35901940.0],
#  'The Road': ['The Road',
#   '2009',
#   '2009-12-18',
#   'R',
#   '7.3',
#   25000000,
#   '111',
#   'Dimension Films',
#   ['Adventure', 'Drama'],
#   17484750.0],
#  'The Romantics': ['The Romantics',
#   '2010',
#   '2010-05-26',
#   'PG-13',
#   '5.1',
#   4500000,
#   '95',
#   '',
#   ['Comedy', 'Drama', 'Romance'],
#   nan],
#  'The Ruins': ['The Ruins',
#   '2008',
#   '2008-04-04',
#   'R',
#   '5.9',
#   8000000,
#   '90',
#   'DreamWorks',
#   ['Horror'],
#   nan],
#  'The Secret Life of Bees': ['The Secret Life of Bees',
#   '2008',
#   '2008-10-17',
#   'PG-13',
#   '7.3',
#   11000000,
#   '114',
#   'Fox Searchlight Pictures',
#   ['Drama'],
#   nan],
#  'The Secret Life of Walter Mitty': ['The Secret Life of Walter Mitty',
#   '2013',
#   '2013-12-25',
#   'PG',
#   '7.3',
#   90000000,
#   '114',
#   'Twentieth Century Fox',
#   ['Adventure', 'Comedy', 'Drama'],
#   80517166.67],
#  'The Secret Scripture': ['The Secret Scripture',
#   '2016',
#   '2017-10-13',
#   'PG-13',
#   '6.7',
#   nan,
#   '108',
#   'Irish Film Board',
#   ['Drama', 'Romance'],
#   28600012.5],
#  'The Sense of an Ending': ['The Sense of an Ending',
#   '2017',
#   '2017-03-10',
#   'PG-13',
#   '6.3',
#   nan,
#   '108',
#   'Origin Pictures',
#   ['Drama', 'Mystery'],
#   nan],
#  'The Snowman': ['The Snowman',
#   '2017',
#   '2017-10-20',
#   'R',
#   '5.1',
#   35000000,
#   '119',
#   'Universal Pictures',
#   ['Crime', 'Drama', 'Mystery'],
#   15351350.0],
#  'The Spectacular Now': ['The Spectacular Now',
#   '2013',
#   '2013-09-13',
#   'R',
#   '7.1',
#   2500000,
#   '95',
#   'Andrew Lauren Productions',
#   ['Comedy', 'Drama', 'Romance'],
#   6564940.0],
#  'The Spiderwick Chronicles': ['The Spiderwick Chronicles',
#   '2008',
#   '2008-02-14',
#   'PG',
#   '6.6',
#   90000000,
#   '96',
#   'Paramount Pictures',
#   ['Adventure', 'Family', 'Fantasy'],
#   nan],
#  'The Spirit': ['The Spirit',
#   '2008',
#   '2008-12-25',
#   'PG-13',
#   '4.8',
#   60000000,
#   '103',
#   'Lionsgate',
#   ['Action', 'Crime', 'Fantasy'],
#   49026200.0],
#  'The Taking of Pelham 123': ['The Taking of Pelham 123',
#   '2009',
#   '2009-06-12',
#   'R',
#   '6.4',
#   100000000,
#   '106',
#   'Columbia Pictures',
#   ['Action', 'Crime', 'Thriller'],
#   133250650.0],
#  'The Tempest': ['The Tempest',
#   '2010',
#   '2011-01-07',
#   'PG-13',
#   '5.4',
#   20000000,
#   '110',
#   'Miramax',
#   ['Comedy', 'Drama', 'Fantasy'],
#   19192925.0],
#  'The Three Musketeers': ['The Three Musketeers',
#   '2011',
#   '2011-10-21',
#   'PG-13',
#   '5.8',
#   75000000,
#   '110',
#   'Summit Entertainment',
#   ['Action', 'Adventure', 'Romance'],
#   nan],
#  "The Time Traveler's Wife": ["The Time Traveler's Wife",
#   '2009',
#   '2009-08-14',
#   'PG-13',
#   '7.1',
#   39000000,
#   '107',
#   'New Line Cinema',
#   ['Drama', 'Fantasy', 'Romance'],
#   93822200.0],
#  "The Vampire's Assistant": ["Cirque du Freak: The Vampire's Assistant",
#   '2009',
#   '2009-10-23',
#   'PG-13',
#   '5.9',
#   40000000,
#   '109',
#   'Universal Pictures',
#   ['Action', 'Adventure', 'Fantasy'],
#   64741750.0],
#  'The Vow': ['The Vow',
#   '2012',
#   '2012-02-10',
#   'PG-13',
#   '6.8',
#   30000000,
#   '104',
#   'Screen Gems',
#   ['Drama', 'Romance'],
#   144849200.0],
#  'The Wind in the Willows': ['The Wind in the Willows',
#   '2006',
#   '2006-12-18',
#   nan,
#   '6.5',
#   nan,
#   '99',
#   'Box TV',
#   ['Adventure', 'Comedy', 'Drama'],
#   nan],
#  'The Woman in Black': ['The Woman in Black',
#   '2012',
#   '2012-02-03',
#   'PG-13',
#   '6.4',
#   17000000,
#   '95',
#   'Cross Creek Pictures',
#   ['Drama', 'Fantasy', 'Horror'],
#   21007900.0],
#  'The Wonderful Wizard of Oz': ['The True Story of the Wonderful Wizard of Oz',
#   '2011',
#   '2011-04-28',
#   nan,
#   '6.7',
#   220000,
#   '60',
#   'Moondance Films',
#   ['Biography'],
#   nan],
#  'The World Made Straight': ['The World Made Straight',
#   '2015',
#   '2015-01-09',
#   'R',
#   '5.5',
#   nan,
#   '119',
#   'Bifrost Pictures',
#   ['Drama'],
#   nan],
#  'This is Where I Leave You': ['This Is Where I Leave You',
#   '2014',
#   '2014-09-19',
#   'R',
#   '6.6',
#   19800000,
#   '103',
#   '',
#   ['Comedy', 'Drama'],
#   133736745.45],
#  'Tinker Tailor Soldier Spy': ['Tinker Tailor Soldier Spy',
#   '2011',
#   '2012-01-06',
#   'R',
#   '7.1',
#   20000000,
#   '122',
#   'StudioCanal',
#   ['Drama', 'Mystery', 'Thriller'],
#   15351350.0],
#  'Trash': ['Trash',
#   '2014',
#   '2015-10-09',
#   'R',
#   '7.2',
#   nan,
#   '114',
#   'Working Title Films',
#   ['Adventure', 'Crime', 'Drama'],
#   35901940.0],
#  'True Grit': ['True Grit',
#   '2010',
#   '2010-12-22',
#   'PG-13',
#   '7.6',
#   38000000,
#   '110',
#   'Paramount Pictures',
#   ['Adventure', 'Drama', 'Western'],
#   53693254.86],
#  'Tulip Fever': ['Tulip Fever',
#   '2017',
#   '2017-09-01',
#   'R',
#   '6.2',
#   25000000,
#   '105',
#   'Worldview Entertainment',
#   ['Drama', 'History', 'Romance'],
#   14712366.67],
#  'Twelve': ['Twelve',
#   '2010',
#   '2010-08-06',
#   'R',
#   '5.7',
#   nan,
#   '93',
#   'Gaumont',
#   ['Action', 'Crime', 'Drama'],
#   90079695.45],
#  'Twilight': ['Twilight',
#   '2008',
#   '2008-11-21',
#   'PG-13',
#   '5.2',
#   37000000,
#   '122',
#   'Summit Entertainment',
#   ['Drama', 'Fantasy', 'Romance'],
#   52255514.29],
#  'Up in the Air': ['Up in the Air',
#   '2009',
#   '2009-12-23',
#   'R',
#   '7.4',
#   25000000,
#   '109',
#   'Paramount Pictures',
#   ['Drama', 'Romance'],
#   58807166.67],
#  'Vampire Academy': ['Vampire Academy',
#   '2014',
#   '2014-02-07',
#   'PG-13',
#   '5.5',
#   30000000,
#   '104',
#   'Angry Films',
#   ['Action', 'Comedy', 'Fantasy'],
#   nan],
#  'Wanted': ['Wanted',
#   '2008',
#   '2008-06-27',
#   'R',
#   '6.7',
#   75000000,
#   '110',
#   'Universal Pictures',
#   ['Action', 'Crime', 'Fantasy'],
#   49260560.0],
#  'War Horse': ['War Horse',
#   '2011',
#   '2011-12-25',
#   'PG-13',
#   '7.2',
#   66000000,
#   '146',
#   'DreamWorks',
#   ['Drama', 'War'],
#   323270386.67],
#  'Warm Bodies': ['Warm Bodies',
#   '2013',
#   '2013-02-01',
#   'PG-13',
#   '6.9',
#   35000000,
#   '98',
#   'Summit Entertainment',
#   ['Comedy', 'Horror', 'Romance'],
#   41450675.0],
#  'Watchmen': ['Watchmen',
#   '2009',
#   '2009-03-06',
#   'R',
#   '7.6',
#   130000000,
#   '162',
#   'Warner Bro',
#   ['Action', 'Drama', 'Mystery'],
#   183172728.57],
#  'Water for Elephants': ['Water for Elephants',
#   '2011',
#   '2011-04-22',
#   'PG-13',
#   '6.9',
#   38000000,
#   '120',
#   'Fox',
#   ['Drama', 'Romance'],
#   275561516.67],
#  'We Need to Talk About Kevin': ['We Need to Talk About Kevin',
#   '2011',
#   '2011-10-21',
#   'R',
#   '7.5',
#   7000000,
#   '112',
#   'BBC Films',
#   ['Drama', 'Mystery', 'Thriller'],
#   928400.0],
#  'What Just Happened?': ['What Just Happened',
#   '2008',
#   '2008-10-31',
#   'R',
#   '5.7',
#   25000000,
#   '104',
#   '',
#   ['Comedy', 'Drama'],
#   79925700.0],
#  'When Worlds Collide': ['When Worlds Collide',
#   'Action',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'Paramount Pictures',
#   ['Action', 'Drama', 'Sci-Fi'],
#   142311687.5],
#  'Where the Wild Things Are': ['Where the Wild Things Are',
#   '2009',
#   '2009-10-16',
#   'PG',
#   '6.8',
#   100000000,
#   '101',
#   'Warner Bro',
#   ['Adventure', 'Drama', 'Family'],
#   49441025.0],
#  'Winnie the Pooh': ['Winnie the Pooh',
#   '2011',
#   '2011-07-15',
#   'G',
#   '7.2',
#   30000000,
#   '63',
#   'Walt Disney Pictures',
#   ['Animation', 'Adventure', 'Comedy'],
#   138812000.0],
#  "Winter's Bone": ["Winter's Bone",
#   '2010',
#   '2010-07-16',
#   'R',
#   '7.2',
#   2000000,
#   '100',
#   'Anonymous Content',
#   ['Drama'],
#   3894900.0],
#  "Winter's Tale": ["Winter's Tale",
#   '2014',
#   '2014-02-14',
#   'PG-13',
#   '6.2',
#   60000000,
#   '118',
#   'Village Roadshow Pictures',
#   ['Drama', 'Fantasy', 'Mystery'],
#   14530300.0],
#  'Wonder': ['Wonder',
#   '2017',
#   '2017-11-17',
#   'PG',
#   '8.0',
#   20000000,
#   '113',
#   'Lionsgate',
#   ['Drama', 'Family'],
#   20254700.0],
#  'World War Z': ['World War Z',
#   '2013',
#   '2013-06-21',
#   'PG-13',
#   '7.0',
#   190000000,
#   '116',
#   'Paramount Pictures',
#   ['Action', 'Adventure', 'Horror'],
#   81596887.5],
#  'Youth in Revolt': ['Youth in Revolt',
#   '2009',
#   '2010-01-08',
#   'R',
#   '6.5',
#   18000000,
#   '90',
#   'Dimension Films',
#   ['Comedy', 'Drama', 'Romance'],
#   24737840.0],
#  'Z for Zachariah': ['Z for Zachariah',
#   '2015',
#   '2015-08-28',
#   'PG-13',
#   '6.0',
#   nan,
#   '98',
#   'Silver Reel',
#   ['Drama', 'Sci-Fi', 'Thriller'],
#   nan]}

# %%
df_imdb = pd.DataFrame.from_dict(dict_imdb, orient='index')

# %%
df_imdb.columns = ['title_imdb','year','release_date','mpaa_rating','user_rating','budget','runtime','production_co','genre','avg_dir_gross']

# %%
df_imdb.head()
# Out:
#                                                       title_imdb  year  \
# The Vow                                                  The Vow  2012
# The Lorax                                              The Lorax  2012
# The Hunger Games                                The Hunger Games  2012
# The Lucky One                                      The Lucky One  2012
# Abraham Lincoln: Vampire Hunter  Abraham Lincoln: Vampire Hunter  2012
#
#                                 release_date mpaa_rating user_rating  \
# The Vow                           2012-02-10       PG-13         6.8
# The Lorax                         2012-03-02          PG         6.4
# The Hunger Games                  2012-03-23       PG-13         7.2
# The Lucky One                     2012-04-20       PG-13         6.5
# Abraham Lincoln: Vampire Hunter   2012-06-22           R         5.9
#
#                                      budget runtime        production_co  \
# The Vow                          30000000.0     104          Screen Gems
# The Lorax                        70000000.0      86   Universal Pictures
# The Hunger Games                 78000000.0     142            Lionsgate
# The Lucky One                    25000000.0     101           Warner Bro
# Abraham Lincoln: Vampire Hunter  69000000.0     105  Abraham Productions
#
#                                                           genre  avg_dir_gross
# The Vow                                        [Drama, Romance]   1.448492e+08
# The Lorax                        [Animation, Adventure, Comedy]   3.435399e+08
# The Hunger Games                  [Adventure, Sci-Fi, Thriller]   1.877139e+08
# The Lucky One                                  [Drama, Romance]   3.749393e+07
# Abraham Lincoln: Vampire Hunter       [Action, Fantasy, Horror]   4.926056e+07

# %%
# create a set of genres since a set contains unique elements
genre_set = set({})
# loop through all the genre lists in the dataframe and add unique elements to the set 
for genre_list in df_imdb['genre']:
    genre_set = genre_set.union(set(genre_list))
genre_set
# Out:
# {'Action',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'Romance',
#  'Sci-Fi',
#  'Short',
#  'Thriller',
#  'War',
#  'Western'}

# %%
# loop through each genre value from the set to create a new col in the df and set values to T/F where the genre is in the film's genre list
for genre_val in genre_set:
    df_imdb[genre_val.lower()] = df_imdb['genre'].apply(lambda x: genre_val in x)

# %%
# biography is a genre that should not be included in this dataset 
df_imdb = df_imdb[df_imdb['biography'] == False]
# drop biography, short, genre columns as they are no longer needed - only interested in fictional and full length films
# reset index and drop the new index column since it is a duplicate
df_imdb.reset_index(inplace=True)
df_imdb.rename(columns={"sci-fi":"scifi",'index':'title'},inplace=True)
df_imdb.drop(columns=['biography','genre','short'],inplace=True)
# music and musical are dupes so they should be combined
df_imdb['musical'] = ((df_imdb['musical']) | (df_imdb['music']))
df_imdb.drop(columns=['music'],inplace=True)

# %%
# check where nulls are
df_imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219 entries, 0 to 218
# Data columns (total 27 columns):
# title            219 non-null object
# title_imdb       219 non-null object
# year             219 non-null object
# release_date     217 non-null object
# mpaa_rating      215 non-null object
# user_rating      217 non-null object
# budget           181 non-null float64
# runtime          218 non-null object
# production_co    217 non-null object
# avg_dir_gross    145 non-null float64
# family           219 non-null bool
# war              219 non-null bool
# thriller         219 non-null bool
# mystery          219 non-null bool
# western          219 non-null bool
# adventure        219 non-null bool
# crime            219 non-null bool
# drama            219 non-null bool
# comedy           219 non-null bool
# romance          219 non-null bool
# fantasy          219 non-null bool
# horror           219 non-null bool
# history          219 non-null bool
# action           219 non-null bool
# musical          219 non-null bool
# animation        219 non-null bool
# scifi            219 non-null bool
# dtypes: bool(17), float64(2), object(8)
# memory usage: 20.8+ KB

# %%
# keep the records where there is a user rating and a release date
df_imdb = df_imdb[df_imdb['user_rating'].notnull()]
df_imdb = df_imdb[df_imdb['release_date'].notnull()]

# %%
df_imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 216 entries, 0 to 218
# Data columns (total 27 columns):
# title            216 non-null object
# title_imdb       216 non-null object
# year             216 non-null object
# release_date     216 non-null object
# mpaa_rating      214 non-null object
# user_rating      216 non-null object
# budget           181 non-null float64
# runtime          216 non-null object
# production_co    215 non-null object
# avg_dir_gross    144 non-null float64
# family           216 non-null bool
# war              216 non-null bool
# thriller         216 non-null bool
# mystery          216 non-null bool
# western          216 non-null bool
# adventure        216 non-null bool
# crime            216 non-null bool
# drama            216 non-null bool
# comedy           216 non-null bool
# romance          216 non-null bool
# fantasy          216 non-null bool
# horror           216 non-null bool
# history          216 non-null bool
# action           216 non-null bool
# musical          216 non-null bool
# animation        216 non-null bool
# scifi            216 non-null bool
# dtypes: bool(17), float64(2), object(8)
# memory usage: 22.1+ KB

# %%
# pickle the dataframe as a saved checkpoint
df_imdb.to_pickle('df_imdb.pkl')

# %%
# find out where the other nulls are and whether they're valid or a result of scraping
df_imdb[df_imdb[['title_imdb','year','release_date','mpaa_rating','budget','runtime','production_co']].isnull().any(axis=1)][['title_imdb','year','release_date','mpaa_rating','user_rating','budget','runtime','production_co']]
# Out:
#                               title_imdb  year release_date mpaa_rating  \
# 10                           Being Flynn  2012   2012-04-19           R
# 12                         Anna Karenina  2012   2012-09-07           R
# 13                               Bel Ami  2012   2012-03-09           R
# 15               The Wind in the Willows  2006   2006-12-18         NaN
# 16                            Coriolanus  2011   2012-01-20           R
# 18                             Jane Eyre  2011   2011-04-22       PG-13
# 28               Horrid Henry: The Movie  2011   2013-01-11          PG
# 30                   Radio Free Albemuth  2010   2014-06-27           R
# 33           Salmon Fishing in the Yemen  2011   2012-04-20       PG-13
# 36                     An Invisible Sign  2010   2010-10-07       PG-13
# 57                    The Garden of Eden  2008   2011-09-15           R
# 65                                Twelve  2010   2010-08-06           R
# 72                      Call of the Wild  2009   2009-06-12          PG
# 87                              Killshot  2008   2008-11-13           R
# 116       Miss Pettigrew Lives for a Day  2008   2008-03-07       PG-13
# 124                 The Secret Scripture  2016   2017-10-13       PG-13
# 125                   The Driftless Area  2015   2016-04-26           R
# 126              The World Made Straight  2015   2015-01-09           R
# 127                      Into the Forest  2015   2016-07-29           R
# 128                      Z for Zachariah  2015   2015-08-28       PG-13
# 131                      A Long Way Down  2014   2014-06-05           R
# 138                                Trash  2014   2015-10-09           R
# 145  Hector and the Search for Happiness  2014   2014-08-14           R
# 162                                Horns  2013   2014-10-03           R
# 163                   Great Expectations  2012   2013-11-08       PG-13
# 169                      The Breadwinner  2017   2017-11-17       PG-13
# 171               The Sense of an Ending  2017   2017-03-10       PG-13
# 172                The House of Tomorrow  2017   2017-04-08         NaN
# 178                     My Cousin Rachel  2017   2017-06-09       PG-13
# 180                           The Dinner  2017   2017-05-05           R
# 186                      Berlin Syndrome  2017   2017-05-26           R
# 197                           The Choice  2016   2016-02-05       PG-13
# 201           The 9th Life of Louis Drax  2016   2016-09-02           R
# 205                               Fallen  2016   2017-09-08       PG-13
# 206                                 Cell  2016   2016-06-10           R
# 216                         Frankenstein  2015   2015-10-29           R
#
#     user_rating     budget runtime                production_co
# 10          6.4        NaN     102               Focus Features
# 12          6.6        NaN     129           Universal Pictures
# 13          5.4        NaN     102                Redwave Films
# 15          6.5        NaN      99                       Box TV
# 16          6.2        NaN     123            Hermetof Pictures
# 18          7.4        NaN     120               Focus Features
# 28          3.7        NaN      93                Vertigo Films
# 30          5.7  3600000.0     111                          NaN
# 33          6.8        NaN     107              UK Film Council
# 36          5.4        NaN      96
# 57          5.4        NaN     111       Devonshire Productions
# 65          5.7        NaN      93                      Gaumont
# 72          5.4        NaN      88       Braeburn Entertainment
# 87          6.0        NaN      95        The Weinstein Company
# 116         7.1        NaN      92               Focus Features
# 124         6.7        NaN     108             Irish Film Board
# 125         5.3        NaN      95             Unified Pictures
# 126         5.5        NaN     119             Bifrost Pictures
# 127         5.9        NaN     101                Rhombus Media
# 128         6.0        NaN      98                  Silver Reel
# 131         6.4        NaN      96               Wildgaze Films
# 138         7.2        NaN     114          Working Title Films
# 145         7.0        NaN     114           Egoli Tossell Film
# 162         6.5        NaN     120         Red Granite Pictures
# 163         6.4        NaN     128                    BBC Films
# 169         7.6        NaN      94            Aircraft Pictures
# 171         6.3        NaN     108              Origin Pictures
# 172         8.1        NaN      85            Superlative Films
# 178         6.0        NaN     106     Fox Searchlight Pictures
# 180         4.5        NaN     120                 ChubbCo Film
# 186         6.3        NaN     116               Aquarius Films
# 197         6.6        NaN     111  Nicholas Sparks Productions
# 201         6.3        NaN     108         Brightlight Pictures
# 205         5.5        NaN      91           Apex Entertainment
# 206         4.3        NaN      98                      Genre C
# 216         5.1        NaN      89                    Bad Badge

# %%
# fill in some holes manually
df_imdb.set_value(30,'production_co','Open Pictures')
df_imdb.set_value(36,'production_co','J2 Pictures')
df_imdb.set_value(15,'mpaa_rating','PG')
df_imdb.set_value(172,'mpaa_rating','R')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   """
#                                            title  \
# 0                                        The Vow
# 1                                      The Lorax
# 2                               The Hunger Games
# 3                                  The Lucky One
# 4                Abraham Lincoln: Vampire Hunter
# 5                                    Cloud Atlas
# 6                                 Les Miserables
# 7                                     Life of Pi
# 8                                    On the Road
# 9                                     Cosmopolis
# 10           Another Bullshit Night in Suck City
# 11               The Perks of Being a Wallflower
# 12                                 Anna Karenina
# 13                                       Bel Ami
# 15                       The Wind in the Willows
# 16                                    Coriolanus
# 17                                       Savages
# 18                                     Jane Eyre
# 19                            The Lincoln Lawyer
# 20                           Water for Elephants
# 21                            Something Borrowed
# 22                                       One Day
# 23                                      The Help
# 24                   We Need to Talk About Kevin
# 25               The Girl with the Dragon Tattoo
# 26                              I Am Number Four
# 27           Extremely Loud and Incredibly Close
# 28                                  Horrid Henry
# 29                             One for the Money
# 30                           Radio Free Albemuth
# ..                                           ...
# 189                             How to Be Single
# 190                                Live By Night
# 191                                Me Before You
# 192  Miss Peregrine's Home for Peculiar Children
# 193                                        Nerve
# 194              Pride and Prejudice and Zombies
# 195                                 The 5th Wave
# 196                                      The BFG
# 197                                   The Choice
# 198                              The Jungle Book
# 199                                      Ben-Hur
# 200                     The Light Between Oceans
# 201                 The Ninth Life of Louis Drax
# 202                        The Girl on the Train
# 203    Middle School: the Worst Years of My Life
# 204                                      Arrival
# 205                                       Fallen
# 206                                         Cell
# 207                      A Hologram for the King
# 208                                  Still Alice
# 209                         Fifty Shades of Grey
# 210                                     The DUFF
# 211                                       Serena
# 212                             The Longest Ride
# 213                                     Child 44
# 214                   Far from the Madding Crowd
# 215                                  Paper Towns
# 216                                 Frankenstein
# 217                                  The Martian
# 218                                  Dark Places
#
#                                       title_imdb  year release_date  \
# 0                                        The Vow  2012   2012-02-10
# 1                                      The Lorax  2012   2012-03-02
# 2                               The Hunger Games  2012   2012-03-23
# 3                                  The Lucky One  2012   2012-04-20
# 4                Abraham Lincoln: Vampire Hunter  2012   2012-06-22
# 5                                    Cloud Atlas  2012   2012-10-26
# 6                                 Les Misérables  2012   2012-12-25
# 7                                     Life of Pi  2012   2012-11-21
# 8                                    On the Road  2012   2012-05-23
# 9                                     Cosmopolis  2012   2012-05-25
# 10                                   Being Flynn  2012   2012-04-19
# 11               The Perks of Being a Wallflower  2012   2012-10-12
# 12                                 Anna Karenina  2012   2012-09-07
# 13                                       Bel Ami  2012   2012-03-09
# 15                       The Wind in the Willows  2006   2006-12-18
# 16                                    Coriolanus  2011   2012-01-20
# 17                                       Savages  2012   2012-07-06
# 18                                     Jane Eyre  2011   2011-04-22
# 19                            The Lincoln Lawyer  2011   2011-03-18
# 20                           Water for Elephants  2011   2011-04-22
# 21                            Something Borrowed  2011   2011-05-06
# 22                                       One Day  2011   2011-08-19
# 23                                      The Help  2011   2011-08-10
# 24                   We Need to Talk About Kevin  2011   2011-10-21
# 25               The Girl with the Dragon Tattoo  2011   2011-12-21
# 26                              I Am Number Four  2011   2011-02-18
# 27             Extremely Loud & Incredibly Close  2011   2012-01-20
# 28                       Horrid Henry: The Movie  2011   2013-01-11
# 29                             One for the Money  2012   2012-01-27
# 30                           Radio Free Albemuth  2010   2014-06-27
# ..                                           ...   ...          ...
# 189                             How to Be Single  2016   2016-02-12
# 190                                Live by Night  2016   2017-01-13
# 191                                Me Before You  2016   2016-06-03
# 192  Miss Peregrine's Home for Peculiar Children  2016   2016-09-30
# 193                                        Nerve  2016   2016-07-27
# 194              Pride and Prejudice and Zombies  2016   2016-02-05
# 195                                 The 5th Wave  2016   2016-01-22
# 196                                      The BFG  2016   2016-07-01
# 197                                   The Choice  2016   2016-02-05
# 198                              The Jungle Book  2016   2016-04-15
# 199                                      Ben-Hur  2016   2016-08-19
# 200                     The Light Between Oceans  2016   2016-09-02
# 201                   The 9th Life of Louis Drax  2016   2016-09-02
# 202                        The Girl on the Train  2016   2016-10-07
# 203    Middle School: The Worst Years of My Life  2016   2016-10-07
# 204                                      Arrival  2016   2016-11-11
# 205                                       Fallen  2016   2017-09-08
# 206                                         Cell  2016   2016-06-10
# 207                      A Hologram for the King  2016   2016-04-28
# 208                                  Still Alice  2014   2015-02-20
# 209                         Fifty Shades of Grey  2015   2015-02-13
# 210                                     The DUFF  2015   2015-02-20
# 211                                       Serena  2014   2015-02-26
# 212                             The Longest Ride  2015   2015-04-10
# 213                                     Child 44  2015   2015-04-17
# 214                   Far from the Madding Crowd  2015   2015-05-22
# 215                                  Paper Towns  2015   2015-07-24
# 216                                 Frankenstein  2015   2015-10-29
# 217                                  The Martian  2015   2015-10-02
# 218                                  Dark Places  2015   2015-06-18
#
#     mpaa_rating user_rating       budget runtime  \
# 0         PG-13         6.8   30000000.0     104
# 1            PG         6.4   70000000.0      86
# 2         PG-13         7.2   78000000.0     142
# 3         PG-13         6.5   25000000.0     101
# 4             R         5.9   69000000.0     105
# 5             R         7.5  102000000.0     172
# 6         PG-13         7.6   61000000.0     158
# 7            PG         7.9  120000000.0     127
# 8             R         6.1   25000000.0     124
# 9             R         5.0   20500000.0     109
# 10            R         6.4          NaN     102
# 11        PG-13         8.0   13000000.0     102
# 12            R         6.6          NaN     129
# 13            R         5.4          NaN     102
# 15           PG         6.5          NaN      99
# 16            R         6.2          NaN     123
# 17            R         6.5   45000000.0     131
# 18        PG-13         7.4          NaN     120
# 19            R         7.3   40000000.0     118
# 20        PG-13         6.9   38000000.0     120
# 21        PG-13         5.9   35000000.0     112
# 22        PG-13         7.0   15000000.0     107
# 23        PG-13         8.1   25000000.0     146
# 24            R         7.5    7000000.0     112
# 25            R         7.8   90000000.0     158
# 26        PG-13         6.1   60000000.0     111
# 27        PG-13         6.9   40000000.0     129
# 28           PG         3.7          NaN      93
# 29        PG-13         5.3   40000000.0      91
# 30            R         5.7    3600000.0     111
# ..          ...         ...          ...     ...
# 189           R         6.1   38000000.0     110
# 190           R         6.4  108000000.0     129
# 191       PG-13         7.4   20000000.0     106
# 192       PG-13         6.7  110000000.0     127
# 193       PG-13         6.6   20000000.0      96
# 194       PG-13         5.8   28000000.0     108
# 195       PG-13         5.2   38000000.0     112
# 196          PG         6.4  140000000.0     117
# 197       PG-13         6.6          NaN     111
# 198          PG         7.5  175000000.0     106
# 199       PG-13         5.7  100000000.0     123
# 200       PG-13         7.2   20000000.0     133
# 201           R         6.3          NaN     108
# 202           R         6.5   45000000.0     112
# 203          PG         6.1    8500000.0      92
# 204       PG-13         7.9   47000000.0     116
# 205       PG-13         5.5          NaN      91
# 206           R         4.3          NaN      98
# 207           R         6.1   30000000.0      98
# 208       PG-13         7.5    5000000.0     101
# 209           R         4.1   40000000.0     125
# 210       PG-13         6.5    8500000.0     101
# 211           R         5.4   30000000.0     109
# 212       PG-13         7.1   34000000.0     123
# 213           R         6.5   50000000.0     137
# 214       PG-13         7.1   12000000.0     119
# 215       PG-13         6.3   12000000.0     109
# 216           R         5.1          NaN      89
# 217       PG-13         8.0  108000000.0     144
# 218           R         6.2   20000000.0     113
#
#                     production_co  avg_dir_gross  ...    drama  comedy  \
# 0                     Screen Gems   1.448492e+08  ...     True   False
# 1              Universal Pictures   3.435399e+08  ...    False    True
# 2                       Lionsgate   1.877139e+08  ...    False   False
# 3                      Warner Bro   3.749393e+07  ...     True   False
# 4             Abraham Productions   4.926056e+07  ...    False   False
# 5         Cloud Atlas Productions   1.027884e+07  ...     True   False
# 6             Working Title Films   8.636660e+07  ...     True   False
# 7                             Fox   6.348579e+07  ...     True   False
# 8                               M            NaN  ...     True   False
# 9                    Alfama Films            NaN  ...     True   False
# 10                 Focus Features   6.474175e+07  ...     True   False
# 11           Summit Entertainment   2.025470e+07  ...     True   False
# 12             Universal Pictures   4.282715e+07  ...     True   False
# 13                  Redwave Films            NaN  ...     True   False
# 15                         Box TV            NaN  ...     True    True
# 16              Hermetof Pictures   1.146550e+06  ...     True   False
# 17                         Ixtlan   7.575237e+07  ...     True   False
# 18                 Focus Features            NaN  ...     True   False
# 19                      Lionsgate   3.496950e+07  ...     True   False
# 20                            Fox   2.755615e+08  ...     True   False
# 21            Alcon Entertainment   6.329495e+07  ...     True    True
# 22                 Focus Features   6.994420e+06  ...     True   False
# 23                     DreamWorks   7.751410e+07  ...     True   False
# 24                      BBC Films   9.284000e+05  ...     True   False
# 25              Columbia Pictures   1.267105e+08  ...     True   False
# 26                     DreamWorks            NaN  ...    False   False
# 27                     Warner Bro   3.590194e+07  ...     True   False
# 28                  Vertigo Films            NaN  ...    False    True
# 29        Lakeshore Entertainment   5.197825e+07  ...    False    True
# 30                  Open Pictures            NaN  ...     True   False
# ..                            ...            ...  ...      ...     ...
# 189               New Line Cinema            NaN  ...    False    True
# 190                    Appian Way   7.537042e+07  ...     True   False
# 191                          Metr            NaN  ...     True   False
# 192         Twentieth Century Fox   1.699500e+08  ...     True   False
# 193  Allison Shearmur Productions   5.720132e+07  ...    False   False
# 194          Cross Creek Pictures   3.382778e+07  ...    False   False
# 195             Columbia Pictures            NaN  ...    False   False
# 196          Walt Disney Pictures   3.232704e+08  ...    False   False
# 197   Nicholas Sparks Productions   2.004070e+07  ...     True   False
# 198        Fairview Entertainment   2.023831e+08  ...     True   False
# 199            LightWorkers Media   4.926056e+07  ...     True   False
# 200                  Heyday Films   1.609957e+07  ...     True   False
# 201          Brightlight Pictures            NaN  ...    False   False
# 202               Amblin Partners   7.751410e+07  ...     True   False
# 203                     CBS Films   9.264358e+07  ...    False    True
# 204               Lava Bear Films   3.790503e+07  ...     True   False
# 205            Apex Entertainment   3.749393e+07  ...     True   False
# 206                       Genre C   3.433873e+07  ...     True   False
# 207                                 1.027884e+07  ...     True    True
# 208                         Lutzu   6.178050e+06  ...     True   False
# 209                Focus Features            NaN  ...     True   False
# 210                      CBS Film   3.839510e+07  ...    False    True
# 211               2929 Production            NaN  ...     True   False
# 212              Fox 2000 Picture            NaN  ...     True   False
# 213        Worldview Entertainmen   4.478945e+07  ...     True   False
# 214       Fox Searchlight Picture            NaN  ...     True   False
# 215              Fox 2000 Picture   1.975645e+07  ...     True   False
# 216                     Bad Badge            NaN  ...    False   False
# 217          Twentieth Century Fo   1.139099e+08  ...     True   False
# 218          Exclusive Media Grou            NaN  ...     True   False
#
#      romance  fantasy  horror  history  action  musical  animation  scifi
# 0       True    False   False    False   False    False      False  False
# 1      False    False   False    False   False    False       True  False
# 2      False    False   False    False   False    False      False   True
# 3       True    False   False    False   False    False      False  False
# 4      False     True    True    False    True    False      False  False
# 5      False    False   False    False    True    False      False  False
# 6      False    False   False     True   False     True      False  False
# 7      False     True   False    False   False    False      False  False
# 8       True    False   False    False   False    False      False  False
# 9      False     True   False    False   False    False      False  False
# 10     False    False   False    False   False    False      False  False
# 11      True    False   False    False   False    False      False  False
# 12      True    False   False    False   False    False      False  False
# 13      True    False   False     True   False    False      False  False
# 15     False    False   False    False   False    False      False  False
# 16     False    False   False    False   False    False      False  False
# 17      True    False   False    False   False    False      False  False
# 18      True    False   False    False   False    False      False  False
# 19     False    False   False    False   False    False      False  False
# 20      True    False   False    False   False    False      False  False
# 21      True    False   False    False   False    False      False  False
# 22      True    False   False    False   False    False      False  False
# 23     False    False   False    False   False    False      False  False
# 24     False    False   False    False   False    False      False  False
# 25     False    False   False    False   False    False      False  False
# 26     False    False   False    False    True    False      False   True
# 27     False    False   False    False   False    False      False  False
# 28     False    False   False    False   False    False      False  False
# 29     False    False   False    False    True    False      False  False
# 30     False    False   False    False   False    False      False   True
# ..       ...      ...     ...      ...     ...      ...        ...    ...
# 189     True    False   False    False   False    False      False  False
# 190    False    False   False    False    True    False      False  False
# 191     True    False   False    False   False    False      False  False
# 192    False    False   False    False   False    False      False  False
# 193    False    False   False    False    True    False      False  False
# 194     True    False    True    False    True    False      False  False
# 195    False    False   False    False    True    False      False   True
# 196    False     True   False    False   False    False      False  False
# 197     True    False   False    False   False    False      False  False
# 198    False    False   False    False   False    False      False  False
# 199    False    False   False    False    True    False      False  False
# 200     True    False   False    False   False    False      False  False
# 201    False    False   False    False   False    False      False  False
# 202    False    False   False    False   False    False      False  False
# 203    False    False   False    False   False    False       True  False
# 204    False    False   False    False   False    False      False   True
# 205    False     True   False    False   False    False      False  False
# 206    False    False    True    False    True    False      False  False
# 207     True    False   False    False   False    False      False  False
# 208    False    False   False    False   False    False      False  False
# 209     True    False   False    False   False    False      False  False
# 210     True    False   False    False   False    False      False  False
# 211     True    False   False    False   False    False      False  False
# 212     True    False   False    False   False    False      False  False
# 213    False    False   False    False   False    False      False  False
# 214     True    False   False    False   False    False      False  False
# 215     True    False   False    False   False    False      False  False
# 216    False    False    True    False   False    False      False  False
# 217    False    False   False    False   False    False      False   True
# 218    False    False   False    False    True    False      False  False
#
# [216 rows x 27 columns]

# %%
df_imdb[(df_imdb['production_co']=='') | (df_imdb['mpaa_rating']=='')]
# Out:
#                            title                   title_imdb  year  \
# 58                 The Romantics                The Romantics  2010
# 114     The Life Before Her Eyes     The Life Before Her Eyes  2007
# 115          Miracle at St. Anna          Miracle at St. Anna  2008
# 119          What Just Happened?           What Just Happened  2008
# 143    This is Where I Leave You    This Is Where I Leave You  2014
# 147  A Walk Among the Tombstones  A Walk Among the Tombstones  2014
# 176                   The Circle                   The Circle  2017
# 207      A Hologram for the King      A Hologram for the King  2016
#
#     release_date mpaa_rating user_rating      budget runtime production_co  \
# 58    2010-05-26       PG-13         5.1   4500000.0      95
# 114   2008-09-05           R         6.4   8000000.0      90
# 115   2008-09-26           R         6.0  45000000.0     160
# 119   2008-10-31           R         5.7  25000000.0     104
# 143   2014-09-19           R         6.6  19800000.0     103
# 147   2014-09-19           R         6.5  28000000.0     114
# 176   2017-04-28       PG-13         5.3  18000000.0     110
# 207   2016-04-28           R         6.1  30000000.0      98
#
#      avg_dir_gross  ...    drama  comedy  romance  fantasy  horror  history  \
# 58             NaN  ...     True    True     True    False   False    False
# 114            NaN  ...     True   False    False     True   False    False
# 115   3.391979e+07  ...     True   False    False    False   False    False
# 119   7.992570e+07  ...     True    True    False    False   False    False
# 143   1.337367e+08  ...     True    True    False    False   False    False
# 147   1.786825e+07  ...     True   False    False    False   False    False
# 176   6.564940e+06  ...     True   False    False    False   False    False
# 207   1.027884e+07  ...     True    True     True    False   False    False
#
#      action  musical  animation  scifi
# 58    False    False      False  False
# 114   False    False      False  False
# 115    True    False      False  False
# 119   False    False      False  False
# 143   False    False      False  False
# 147   False    False      False  False
# 176   False    False      False   True
# 207   False    False      False  False
#
# [8 rows x 27 columns]

# %%
# fill in some holes manually
df_imdb.set_value(58,'production_co','10th Hole Productions')
df_imdb.set_value(114,'production_co','2929 Productions')
df_imdb.set_value(115,'production_co','40 Acres & A Mule Filmworks')
df_imdb.set_value(119,'production_co','2929 Productions')
df_imdb.set_value(143,'production_co','Warner Bro')
df_imdb.set_value(147,'production_co','1984 Private Defense Contractors')
df_imdb.set_value(176,'production_co','1978 Films')
df_imdb.set_value(207,'production_co','X-Filme Creative Pool')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if __name__ == '__main__':
#                                            title  \
# 0                                        The Vow
# 1                                      The Lorax
# 2                               The Hunger Games
# 3                                  The Lucky One
# 4                Abraham Lincoln: Vampire Hunter
# 5                                    Cloud Atlas
# 6                                 Les Miserables
# 7                                     Life of Pi
# 8                                    On the Road
# 9                                     Cosmopolis
# 10           Another Bullshit Night in Suck City
# 11               The Perks of Being a Wallflower
# 12                                 Anna Karenina
# 13                                       Bel Ami
# 15                       The Wind in the Willows
# 16                                    Coriolanus
# 17                                       Savages
# 18                                     Jane Eyre
# 19                            The Lincoln Lawyer
# 20                           Water for Elephants
# 21                            Something Borrowed
# 22                                       One Day
# 23                                      The Help
# 24                   We Need to Talk About Kevin
# 25               The Girl with the Dragon Tattoo
# 26                              I Am Number Four
# 27           Extremely Loud and Incredibly Close
# 28                                  Horrid Henry
# 29                             One for the Money
# 30                           Radio Free Albemuth
# ..                                           ...
# 189                             How to Be Single
# 190                                Live By Night
# 191                                Me Before You
# 192  Miss Peregrine's Home for Peculiar Children
# 193                                        Nerve
# 194              Pride and Prejudice and Zombies
# 195                                 The 5th Wave
# 196                                      The BFG
# 197                                   The Choice
# 198                              The Jungle Book
# 199                                      Ben-Hur
# 200                     The Light Between Oceans
# 201                 The Ninth Life of Louis Drax
# 202                        The Girl on the Train
# 203    Middle School: the Worst Years of My Life
# 204                                      Arrival
# 205                                       Fallen
# 206                                         Cell
# 207                      A Hologram for the King
# 208                                  Still Alice
# 209                         Fifty Shades of Grey
# 210                                     The DUFF
# 211                                       Serena
# 212                             The Longest Ride
# 213                                     Child 44
# 214                   Far from the Madding Crowd
# 215                                  Paper Towns
# 216                                 Frankenstein
# 217                                  The Martian
# 218                                  Dark Places
#
#                                       title_imdb  year release_date  \
# 0                                        The Vow  2012   2012-02-10
# 1                                      The Lorax  2012   2012-03-02
# 2                               The Hunger Games  2012   2012-03-23
# 3                                  The Lucky One  2012   2012-04-20
# 4                Abraham Lincoln: Vampire Hunter  2012   2012-06-22
# 5                                    Cloud Atlas  2012   2012-10-26
# 6                                 Les Misérables  2012   2012-12-25
# 7                                     Life of Pi  2012   2012-11-21
# 8                                    On the Road  2012   2012-05-23
# 9                                     Cosmopolis  2012   2012-05-25
# 10                                   Being Flynn  2012   2012-04-19
# 11               The Perks of Being a Wallflower  2012   2012-10-12
# 12                                 Anna Karenina  2012   2012-09-07
# 13                                       Bel Ami  2012   2012-03-09
# 15                       The Wind in the Willows  2006   2006-12-18
# 16                                    Coriolanus  2011   2012-01-20
# 17                                       Savages  2012   2012-07-06
# 18                                     Jane Eyre  2011   2011-04-22
# 19                            The Lincoln Lawyer  2011   2011-03-18
# 20                           Water for Elephants  2011   2011-04-22
# 21                            Something Borrowed  2011   2011-05-06
# 22                                       One Day  2011   2011-08-19
# 23                                      The Help  2011   2011-08-10
# 24                   We Need to Talk About Kevin  2011   2011-10-21
# 25               The Girl with the Dragon Tattoo  2011   2011-12-21
# 26                              I Am Number Four  2011   2011-02-18
# 27             Extremely Loud & Incredibly Close  2011   2012-01-20
# 28                       Horrid Henry: The Movie  2011   2013-01-11
# 29                             One for the Money  2012   2012-01-27
# 30                           Radio Free Albemuth  2010   2014-06-27
# ..                                           ...   ...          ...
# 189                             How to Be Single  2016   2016-02-12
# 190                                Live by Night  2016   2017-01-13
# 191                                Me Before You  2016   2016-06-03
# 192  Miss Peregrine's Home for Peculiar Children  2016   2016-09-30
# 193                                        Nerve  2016   2016-07-27
# 194              Pride and Prejudice and Zombies  2016   2016-02-05
# 195                                 The 5th Wave  2016   2016-01-22
# 196                                      The BFG  2016   2016-07-01
# 197                                   The Choice  2016   2016-02-05
# 198                              The Jungle Book  2016   2016-04-15
# 199                                      Ben-Hur  2016   2016-08-19
# 200                     The Light Between Oceans  2016   2016-09-02
# 201                   The 9th Life of Louis Drax  2016   2016-09-02
# 202                        The Girl on the Train  2016   2016-10-07
# 203    Middle School: The Worst Years of My Life  2016   2016-10-07
# 204                                      Arrival  2016   2016-11-11
# 205                                       Fallen  2016   2017-09-08
# 206                                         Cell  2016   2016-06-10
# 207                      A Hologram for the King  2016   2016-04-28
# 208                                  Still Alice  2014   2015-02-20
# 209                         Fifty Shades of Grey  2015   2015-02-13
# 210                                     The DUFF  2015   2015-02-20
# 211                                       Serena  2014   2015-02-26
# 212                             The Longest Ride  2015   2015-04-10
# 213                                     Child 44  2015   2015-04-17
# 214                   Far from the Madding Crowd  2015   2015-05-22
# 215                                  Paper Towns  2015   2015-07-24
# 216                                 Frankenstein  2015   2015-10-29
# 217                                  The Martian  2015   2015-10-02
# 218                                  Dark Places  2015   2015-06-18
#
#     mpaa_rating user_rating       budget runtime  \
# 0         PG-13         6.8   30000000.0     104
# 1            PG         6.4   70000000.0      86
# 2         PG-13         7.2   78000000.0     142
# 3         PG-13         6.5   25000000.0     101
# 4             R         5.9   69000000.0     105
# 5             R         7.5  102000000.0     172
# 6         PG-13         7.6   61000000.0     158
# 7            PG         7.9  120000000.0     127
# 8             R         6.1   25000000.0     124
# 9             R         5.0   20500000.0     109
# 10            R         6.4          NaN     102
# 11        PG-13         8.0   13000000.0     102
# 12            R         6.6          NaN     129
# 13            R         5.4          NaN     102
# 15           PG         6.5          NaN      99
# 16            R         6.2          NaN     123
# 17            R         6.5   45000000.0     131
# 18        PG-13         7.4          NaN     120
# 19            R         7.3   40000000.0     118
# 20        PG-13         6.9   38000000.0     120
# 21        PG-13         5.9   35000000.0     112
# 22        PG-13         7.0   15000000.0     107
# 23        PG-13         8.1   25000000.0     146
# 24            R         7.5    7000000.0     112
# 25            R         7.8   90000000.0     158
# 26        PG-13         6.1   60000000.0     111
# 27        PG-13         6.9   40000000.0     129
# 28           PG         3.7          NaN      93
# 29        PG-13         5.3   40000000.0      91
# 30            R         5.7    3600000.0     111
# ..          ...         ...          ...     ...
# 189           R         6.1   38000000.0     110
# 190           R         6.4  108000000.0     129
# 191       PG-13         7.4   20000000.0     106
# 192       PG-13         6.7  110000000.0     127
# 193       PG-13         6.6   20000000.0      96
# 194       PG-13         5.8   28000000.0     108
# 195       PG-13         5.2   38000000.0     112
# 196          PG         6.4  140000000.0     117
# 197       PG-13         6.6          NaN     111
# 198          PG         7.5  175000000.0     106
# 199       PG-13         5.7  100000000.0     123
# 200       PG-13         7.2   20000000.0     133
# 201           R         6.3          NaN     108
# 202           R         6.5   45000000.0     112
# 203          PG         6.1    8500000.0      92
# 204       PG-13         7.9   47000000.0     116
# 205       PG-13         5.5          NaN      91
# 206           R         4.3          NaN      98
# 207           R         6.1   30000000.0      98
# 208       PG-13         7.5    5000000.0     101
# 209           R         4.1   40000000.0     125
# 210       PG-13         6.5    8500000.0     101
# 211           R         5.4   30000000.0     109
# 212       PG-13         7.1   34000000.0     123
# 213           R         6.5   50000000.0     137
# 214       PG-13         7.1   12000000.0     119
# 215       PG-13         6.3   12000000.0     109
# 216           R         5.1          NaN      89
# 217       PG-13         8.0  108000000.0     144
# 218           R         6.2   20000000.0     113
#
#                     production_co  avg_dir_gross  ...    drama  comedy  \
# 0                     Screen Gems   1.448492e+08  ...     True   False
# 1              Universal Pictures   3.435399e+08  ...    False    True
# 2                       Lionsgate   1.877139e+08  ...    False   False
# 3                      Warner Bro   3.749393e+07  ...     True   False
# 4             Abraham Productions   4.926056e+07  ...    False   False
# 5         Cloud Atlas Productions   1.027884e+07  ...     True   False
# 6             Working Title Films   8.636660e+07  ...     True   False
# 7                             Fox   6.348579e+07  ...     True   False
# 8                               M            NaN  ...     True   False
# 9                    Alfama Films            NaN  ...     True   False
# 10                 Focus Features   6.474175e+07  ...     True   False
# 11           Summit Entertainment   2.025470e+07  ...     True   False
# 12             Universal Pictures   4.282715e+07  ...     True   False
# 13                  Redwave Films            NaN  ...     True   False
# 15                         Box TV            NaN  ...     True    True
# 16              Hermetof Pictures   1.146550e+06  ...     True   False
# 17                         Ixtlan   7.575237e+07  ...     True   False
# 18                 Focus Features            NaN  ...     True   False
# 19                      Lionsgate   3.496950e+07  ...     True   False
# 20                            Fox   2.755615e+08  ...     True   False
# 21            Alcon Entertainment   6.329495e+07  ...     True    True
# 22                 Focus Features   6.994420e+06  ...     True   False
# 23                     DreamWorks   7.751410e+07  ...     True   False
# 24                      BBC Films   9.284000e+05  ...     True   False
# 25              Columbia Pictures   1.267105e+08  ...     True   False
# 26                     DreamWorks            NaN  ...    False   False
# 27                     Warner Bro   3.590194e+07  ...     True   False
# 28                  Vertigo Films            NaN  ...    False    True
# 29        Lakeshore Entertainment   5.197825e+07  ...    False    True
# 30                  Open Pictures            NaN  ...     True   False
# ..                            ...            ...  ...      ...     ...
# 189               New Line Cinema            NaN  ...    False    True
# 190                    Appian Way   7.537042e+07  ...     True   False
# 191                          Metr            NaN  ...     True   False
# 192         Twentieth Century Fox   1.699500e+08  ...     True   False
# 193  Allison Shearmur Productions   5.720132e+07  ...    False   False
# 194          Cross Creek Pictures   3.382778e+07  ...    False   False
# 195             Columbia Pictures            NaN  ...    False   False
# 196          Walt Disney Pictures   3.232704e+08  ...    False   False
# 197   Nicholas Sparks Productions   2.004070e+07  ...     True   False
# 198        Fairview Entertainment   2.023831e+08  ...     True   False
# 199            LightWorkers Media   4.926056e+07  ...     True   False
# 200                  Heyday Films   1.609957e+07  ...     True   False
# 201          Brightlight Pictures            NaN  ...    False   False
# 202               Amblin Partners   7.751410e+07  ...     True   False
# 203                     CBS Films   9.264358e+07  ...    False    True
# 204               Lava Bear Films   3.790503e+07  ...     True   False
# 205            Apex Entertainment   3.749393e+07  ...     True   False
# 206                       Genre C   3.433873e+07  ...     True   False
# 207         X-Filme Creative Pool   1.027884e+07  ...     True    True
# 208                         Lutzu   6.178050e+06  ...     True   False
# 209                Focus Features            NaN  ...     True   False
# 210                      CBS Film   3.839510e+07  ...    False    True
# 211               2929 Production            NaN  ...     True   False
# 212              Fox 2000 Picture            NaN  ...     True   False
# 213        Worldview Entertainmen   4.478945e+07  ...     True   False
# 214       Fox Searchlight Picture            NaN  ...     True   False
# 215              Fox 2000 Picture   1.975645e+07  ...     True   False
# 216                     Bad Badge            NaN  ...    False   False
# 217          Twentieth Century Fo   1.139099e+08  ...     True   False
# 218          Exclusive Media Grou            NaN  ...     True   False
#
#      romance  fantasy  horror  history  action  musical  animation  scifi
# 0       True    False   False    False   False    False      False  False
# 1      False    False   False    False   False    False       True  False
# 2      False    False   False    False   False    False      False   True
# 3       True    False   False    False   False    False      False  False
# 4      False     True    True    False    True    False      False  False
# 5      False    False   False    False    True    False      False  False
# 6      False    False   False     True   False     True      False  False
# 7      False     True   False    False   False    False      False  False
# 8       True    False   False    False   False    False      False  False
# 9      False     True   False    False   False    False      False  False
# 10     False    False   False    False   False    False      False  False
# 11      True    False   False    False   False    False      False  False
# 12      True    False   False    False   False    False      False  False
# 13      True    False   False     True   False    False      False  False
# 15     False    False   False    False   False    False      False  False
# 16     False    False   False    False   False    False      False  False
# 17      True    False   False    False   False    False      False  False
# 18      True    False   False    False   False    False      False  False
# 19     False    False   False    False   False    False      False  False
# 20      True    False   False    False   False    False      False  False
# 21      True    False   False    False   False    False      False  False
# 22      True    False   False    False   False    False      False  False
# 23     False    False   False    False   False    False      False  False
# 24     False    False   False    False   False    False      False  False
# 25     False    False   False    False   False    False      False  False
# 26     False    False   False    False    True    False      False   True
# 27     False    False   False    False   False    False      False  False
# 28     False    False   False    False   False    False      False  False
# 29     False    False   False    False    True    False      False  False
# 30     False    False   False    False   False    False      False   True
# ..       ...      ...     ...      ...     ...      ...        ...    ...
# 189     True    False   False    False   False    False      False  False
# 190    False    False   False    False    True    False      False  False
# 191     True    False   False    False   False    False      False  False
# 192    False    False   False    False   False    False      False  False
# 193    False    False   False    False    True    False      False  False
# 194     True    False    True    False    True    False      False  False
# 195    False    False   False    False    True    False      False   True
# 196    False     True   False    False   False    False      False  False
# 197     True    False   False    False   False    False      False  False
# 198    False    False   False    False   False    False      False  False
# 199    False    False   False    False    True    False      False  False
# 200     True    False   False    False   False    False      False  False
# 201    False    False   False    False   False    False      False  False
# 202    False    False   False    False   False    False      False  False
# 203    False    False   False    False   False    False       True  False
# 204    False    False   False    False   False    False      False   True
# 205    False     True   False    False   False    False      False  False
# 206    False    False    True    False    True    False      False  False
# 207     True    False   False    False   False    False      False  False
# 208    False    False   False    False   False    False      False  False
# 209     True    False   False    False   False    False      False  False
# 210     True    False   False    False   False    False      False  False
# 211     True    False   False    False   False    False      False  False
# 212     True    False   False    False   False    False      False  False
# 213    False    False   False    False   False    False      False  False
# 214     True    False   False    False   False    False      False  False
# 215     True    False   False    False   False    False      False  False
# 216    False    False    True    False   False    False      False  False
# 217    False    False   False    False   False    False      False   True
# 218    False    False   False    False    True    False      False  False
#
# [216 rows x 27 columns]

# %%
df_imdb['user_rating'] = pd.to_numeric(df_imdb['user_rating'], downcast = 'float')
df_imdb['runtime'] = pd.to_numeric(df_imdb['runtime'], downcast = 'float')
df_imdb['release_date'] = pd.to_datetime(df_imdb['release_date'], format = '%Y-%m-%d', errors='ignore')

# %%
# the nulls are significant for avg_dir_gross so they will be set to 0 and a boolean variable added to represent whether the directors are well-known
df_imdb.loc[(df_imdb['avg_dir_gross'].isnull()),'avg_dir_gross'] = 0
df_imdb['dir_accomplished'] = (df_imdb['avg_dir_gross']>0)

# %%
df_imdb.reset_index(inplace=True,drop=True)

# %%
df_imdb.head()
# Out:
#                              title                       title_imdb  year  \
# 0                          The Vow                          The Vow  2012
# 1                        The Lorax                        The Lorax  2012
# 2                 The Hunger Games                 The Hunger Games  2012
# 3                    The Lucky One                    The Lucky One  2012
# 4  Abraham Lincoln: Vampire Hunter  Abraham Lincoln: Vampire Hunter  2012
#
#   release_date mpaa_rating  user_rating      budget  runtime  \
# 0   2012-02-10       PG-13          6.8  30000000.0    104.0
# 1   2012-03-02          PG          6.4  70000000.0     86.0
# 2   2012-03-23       PG-13          7.2  78000000.0    142.0
# 3   2012-04-20       PG-13          6.5  25000000.0    101.0
# 4   2012-06-22           R          5.9  69000000.0    105.0
#
#          production_co  avg_dir_gross        ...         comedy  romance  \
# 0          Screen Gems   1.448492e+08        ...          False     True
# 1   Universal Pictures   3.435399e+08        ...           True    False
# 2            Lionsgate   1.877139e+08        ...          False    False
# 3           Warner Bro   3.749393e+07        ...          False     True
# 4  Abraham Productions   4.926056e+07        ...          False    False
#
#    fantasy  horror  history  action  musical  animation  scifi  \
# 0    False   False    False   False    False      False  False
# 1    False   False    False   False    False       True  False
# 2    False   False    False   False    False      False   True
# 3    False   False    False   False    False      False  False
# 4     True    True    False    True    False      False  False
#
#    dir_accomplished
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True
#
# [5 rows x 28 columns]

# %%
# let's look at production company values
df_imdb.groupby(['production_co']).size().reset_index(name='Freq').sort_values(by=['Freq'],ascending=False)
# Out:
#                           production_co  Freq
# 119                          Warner Bro    12
# 111               Twentieth Century Fox     9
# 56                       Focus Features     8
# 114                  Universal Pictures     8
# 47                           DreamWorks     7
# 105                Summit Entertainment     6
# 86                      New Line Cinema     6
# 118                Walt Disney Pictures     6
# 57                                  Fox     5
# 39                    Columbia Pictures     5
# 91                   Paramount Pictures     5
# 79                            Lionsgate     4
# 100                         Screen Gems     4
# 61             Fox Searchlight Pictures     3
# 48                 DreamWorks Animation     2
# 84                              Miramax     2
# 23                            BBC Films     2
# 32                            CBS Films     2
# 98                        Rhombus Media     2
# 83                                 Metr     2
# 41                 Cross Creek Pictures     2
# 104                         StudioCanal     2
# 97                     Relativity Media     2
# 46                      Dimension Films     2
# 45                      DiNovi Pictures     2
# 8                   Alcon Entertainment     2
# 58                     Fox 2000 Picture     2
# 4                      2929 Productions     2
# 121                 Working Title Films     2
# 12                 Amblin Entertainment     2
# ..                                  ...   ...
# 3                       2929 Production     1
# 2      1984 Private Defense Contractors     1
# 30                 Brightlight Pictures     1
# 31                             CBS Film     1
# 33   Castle Rock Entertainment See more     1
# 34                Chernin Entertainment     1
# 67                         Heyday Films     1
# 66                   Hero Entertainment     1
# 65                    Hermetof Pictures     1
# 64               Ghoulardi Film Company     1
# 63                              Genre C     1
# 1                            1978 Films     1
# 60              Fox Searchlight Picture     1
# 59                           Fox Atomic     1
# 55                    Fickle Fish Films     1
# 54               Fairview Entertainment     1
# 53                 Exclusive Media Grou     1
# 52                     Element Pictures     1
# 51                   Egoli Tossell Film     1
# 50                         Ecosse Films     1
# 49                                 EFTI     1
# 44               Devonshire Productions     1
# 43                            DNA Films     1
# 42                     Curmudgeon Films     1
# 40                      Constantin Film     1
# 38                          Color Force     1
# 37              Cloud Atlas Productions     1
# 36                         ChubbCo Film     1
# 35                  Chockstone Pictures     1
# 124               X-Filme Creative Pool     1
#
# [125 rows x 2 columns]

# %% [markdown]
# Looks like there are some different variations of the same production companies. These will need to be standardized.

# %%
df_imdb.loc[df_imdb['production_co'].str.contains('Fox'), 'production_co'] = 'Fox'
df_imdb.loc[df_imdb['production_co'].str.contains('Warner'), 'production_co'] = 'Warner'
df_imdb.loc[df_imdb['production_co'].str.contains('Disney'), 'production_co'] = 'Disney'
df_imdb.loc[df_imdb['production_co'].str.contains('Universal'), 'production_co'] = 'Universal'
df_imdb.loc[df_imdb['production_co'].str.contains('DreamWorks'), 'production_co'] = 'DreamWorks'

# %%
# tried making this an iterable or function but the regex wouldn't search properly
regex = r'Film$'
df_imdb['production_co'] = df_imdb['production_co'].apply(lambda x: re.sub(regex,'',x.strip()))
regex = r'Films$'
df_imdb['production_co'] = df_imdb['production_co'].apply(lambda x: re.sub(regex,'',x.strip()))
regex = r'Picture$'
df_imdb['production_co'] = df_imdb['production_co'].apply(lambda x: re.sub(regex,'',x.strip()))
regex = r'Pictures$'
df_imdb['production_co'] = df_imdb['production_co'].apply(lambda x: re.sub(regex,'',x.strip()))
regex = r'Feature$'
df_imdb['production_co'] = df_imdb['production_co'].apply(lambda x: re.sub(regex,'',x.strip()))
regex = r'Features$'
df_imdb['production_co'] = df_imdb['production_co'].apply(lambda x: re.sub(regex,'',x.strip()))
regex = r'Production$'
df_imdb['production_co'] = df_imdb['production_co'].apply(lambda x: re.sub(regex,'',x.strip()))
regex = r'Productions$'
df_imdb['production_co'] = df_imdb['production_co'].apply(lambda x: re.sub(regex,'',x.strip()))
regex = r'Media$'
df_imdb['production_co'] = df_imdb['production_co'].apply(lambda x: re.sub(regex,'',x.strip()))
regex = r'Entertainment$'
df_imdb['production_co'] = df_imdb['production_co'].apply(lambda x: re.sub(regex,'',x.strip()))
regex = r'See more$'
df_imdb['production_co'] = df_imdb['production_co'].apply(lambda x: re.sub(regex,'',x.strip()))

# %%
# now let's look at production company after standardizing
df_company_freq = df_imdb.groupby(['production_co']).size().reset_index(name='Freq').sort_values(by=['Freq'],ascending=False)
df_company_freq
# Out:
#                         production_co  Freq
# 55                                Fox    21
# 111                            Warner    12
# 46                         DreamWorks     9
# 54                              Focus     8
# 107                         Universal     8
# 80                    New Line Cinema     6
# 45                             Disney     6
# 99                             Summit     6
# 85                          Paramount     5
# 37                           Columbia     5
# 94                        Screen Gems     4
# 73                          Lionsgate     4
# 3                                2929     3
# 30                                CBS     3
# 11                             Amblin     2
# 39                        Cross Creek     2
# 78                            Miramax     2
# 77                               Metr     2
# 98                        StudioCanal     2
# 22                                BBC     2
# 91                         Relativity     2
# 44                          Dimension     2
# 101             The Weinstein Company     2
# 113                     Working Title     2
# 7                               Alcon     2
# 43                             DiNovi     2
# 92                            Rhombus     2
# 81                    Nicholas Sparks     1
# 0                           10th Hole     1
# 76                                MWM     1
# ..                                ...   ...
# 5                             Abraham     1
# 4         40 Acres & A Mule Filmworks     1
# 2    1984 Private Defense Contractors     1
# 28                           Braeburn     1
# 31         Castle Rock Entertainment      1
# 63                          IM Global     1
# 50                            Element     1
# 62                   IDG China Media      1
# 61                             Heyday     1
# 60                               Hero     1
# 59                           Hermetof     1
# 1                                1978     1
# 57                            Genre C     1
# 56                            Gaumont     1
# 53                        Fickle Fish     1
# 52                           Fairview     1
# 51               Exclusive Media Grou     1
# 49                      Egoli Tossell     1
# 32                            Chernin     1
# 48                             Ecosse     1
# 47                               EFTI     1
# 42                         Devonshire     1
# 41                                DNA     1
# 40                         Curmudgeon     1
# 38                         Constantin     1
# 36                        Color Force     1
# 35                        Cloud Atlas     1
# 34                            ChubbCo     1
# 33                         Chockstone     1
# 116             X-Filme Creative Pool     1
#
# [117 rows x 2 columns]

# %% [markdown]
# There are still so many unique production company values. Let's see if we can quantify these by market share.

# %%
driver = webdriver.Chrome(chromedriver)
driver.get('http://www.boxofficemojo.com/studio/?view=parent&view2=yearly&yr=2017')

# %%
df_company = pd.read_html(driver.current_url, header=0, parse_dates=True)[2]
df_company.columns = ['rank','company','market_share','total_gross','movies_tracked','2017_movies']
df_company['market_share'] = df_company['market_share'].apply(lambda x: x[:-1]).astype(float)
df_company[['company','market_share']].to_csv('company.csv',sep=',',index=False)

# %%
driver.get('http://www.boxofficemojo.com/studio/?view=company&view2=yearly&yr=2017')

# %%
df_company2 = pd.read_html(driver.current_url, header=0, parse_dates=True)[2]
df_company2.columns = ['rank','company','market_share','total_gross','movies_tracked','2017_movies']
df_company2['market_share'] = df_company2['market_share'].apply(lambda x: x[:-1]).astype(float)
df_company2[['company','market_share']].to_csv('company2.csv',sep=',',index=False)

# %%
df_company_trim = pd.read_csv('company.csv',sep=',')

# %%
df_company_trim.head()
# Out:
#        company  market_share
# 0  Buena Vista          21.8
# 1     Columbia           9.6
# 2        Focus           1.2
# 3       Disney          21.8
# 4       Warner          18.4

# %%
share_list = []
for val in df_imdb['production_co']:
    match = 0
    counter = 0
    max_counter = len(df_company_trim['company'])
    while (match==0) and (counter<max_counter):
        if df_company_trim['company'][counter].find(val) > -1:
            match = 1
        else:
            counter +=1
    try:
        share_list.append(df_company_trim['market_share'][counter])
    except:
        share_list.append(np.nan)

# %%
df_imdb['market_share'] = share_list

# %%
df_imdb[['production_co','market_share']].head()
# Out:
#   production_co  market_share
# 0   Screen Gems           NaN
# 1     Universal          15.0
# 2     Lionsgate           8.0
# 3        Warner          18.4
# 4       Abraham           NaN

# %%
df_imdb.loc[df_imdb['market_share'].isnull(), 'market_share'] = 0

# %%
# now production_co can be dropped
df_imdb.drop(columns=['production_co'],inplace=True)

# %%
# make dummy variable for mpaa_rating
df_mpaa = pd.get_dummies(df_imdb['mpaa_rating'], prefix='mpaa', drop_first=True)

# %%
df_imdb = df_imdb.join(df_mpaa)

# %%
df_imdb.rename(columns={'mpaa_PG':'mpaa_pg','mpaa_PG-13':'mpaa_pg13','mpaa_R':'mpaa_r'},inplace=True)
df_imdb.drop(columns=['mpaa_rating','budget','release_date'],inplace=True)

# %%
df_imdb.head()
# Out:
#                              title                       title_imdb  year  \
# 0                          The Vow                          The Vow  2012
# 1                        The Lorax                        The Lorax  2012
# 2                 The Hunger Games                 The Hunger Games  2012
# 3                    The Lucky One                    The Lucky One  2012
# 4  Abraham Lincoln: Vampire Hunter  Abraham Lincoln: Vampire Hunter  2012
#
#    user_rating  runtime  avg_dir_gross  family    war  thriller  mystery  \
# 0          6.8    104.0   1.448492e+08   False  False     False    False
# 1          6.4     86.0   3.435399e+08   False  False     False    False
# 2          7.2    142.0   1.877139e+08   False  False      True    False
# 3          6.5    101.0   3.749393e+07   False  False     False    False
# 4          5.9    105.0   4.926056e+07   False  False     False    False
#
#     ...    history  action  musical  animation  scifi  dir_accomplished  \
# 0   ...      False   False    False      False  False              True
# 1   ...      False   False    False       True  False              True
# 2   ...      False   False    False      False   True              True
# 3   ...      False   False    False      False  False              True
# 4   ...      False    True    False      False  False              True
#
#    market_share  mpaa_pg  mpaa_pg13  mpaa_r
# 0           0.0        0          1       0
# 1          15.0        1          0       0
# 2           8.0        0          1       0
# 3          18.4        0          1       0
# 4           0.0        0          0       1
#
# [5 rows x 28 columns]

# %%
# pickle the dataframe as a saved checkpoint
df_imdb.to_pickle('df_imdb_clean.pkl')
